# %% [markdown]
# [Formulynas](../../formulynas.png)

# %% [markdown]
# ## Bandomasis PUPP Nr. 1 | 2025
# * Patikrinimą sudaro 30 uždavinių.
# * Patikrinimo taškų suma yra 50 taškų.
# * Patikrinimo trukmė – 150 min.
# * Šaltinis: [Elicėjus, laikina nemokama prieiga](https://mokinys.elicejus.lt/dashboard/1/public-test/4006)

# %% [markdown]
# 1\. Duota kvadratinė lygtis $-2x^2 + x - 1 = 0$.
# * Koks yra šios kvadratinės lygties diskriminantas $D$? (**1 tšk.**)
# * Kuris teiginys teisingas?  (**1 tšk.**)
# $\begin{array}{ll}
# \boxed{A}\, \text{Lygtis turi du sprendinius} \\
# \boxed{B}\, \text{Lygtis turi vieną sprendinį} \\
# \boxed{C}\, \text{Lygtis turi daugiau nei vieną sprendinį} \\
# \boxed{D}\, \text{Lygtis neturi sprendinių}
# \end{array}$
#
# 2\. Brėžinyje pavaizduotas funkcijos $f(x)=ax^2+bx+c$ grafiko eskizas. Kuris teiginys **neteisingas**? (**1 tšk.**)
# Pastaba $D$ - lygties $ax^2+bx+c=0$ diskriminantas.
# <img src="../images/2025b1_1.png" width="120"/>
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, D<0 &
# \boxed{B}\, a>0 &
# \boxed{C}\, b>0 &
# \boxed{D}\, c>0
# \end{array}$
#
# 3\. Nubrėžta kampo pusiaukampinė prieš ją esančią kraštinę dalija į atkarpas $t=8$ ir $s=28$. Viena trikampio kraštinė $r=42$. Apskaičiuok kraštinės $p$ ilgį (**1 tšk.**)
# <img src="../images/2025b1_3.png" width="80"/>
#
# 4\. Apie lygiakraštį trikampį $ABC$ apibrėžtas apskritimas. Koks pažymėto lanko $AB$ didumas? (**1 tšk.**)
# <img src="../images/2025b1_4.png" width="120"/>
#
# 5\. Pagal duotus paveiksliukus, pasirink apytikslę koreliacijos koeficiento reikšmę iš duotų galimų (**2 tšk.**)
# <img src="../images/2025b1_5_1.png" width="150"/>
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, r=-0{,}9 &
# \boxed{B}\, r=-0{,}5 &
# \boxed{C}\, r=0{,}5 &
# \boxed{D}\, r=0{,}9
# \end{array}$
# <img src="../images/2025b1_5_2.png" width="150"/>
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, r=-0{,}9 &
# \boxed{B}\, r=-0{,}5 &
# \boxed{C}\, r=0{,}5 &
# \boxed{D}\, r=0{,}9
# \end{array}$
#
# 6\. Stačiojo trikampio $NPO$ statiniai $NP = 24\,\text{cm}$; $NO = 10\,\text{cm}$
# <img src="../images/2025b1_6.png" width="80"/>
# Apskaičiuok $\text{tg}(\angle NPO)$ ir $\cos (\angle NOP)$  (**2 tšk.**)
#
# 7\. Brėžiniuose pavaizduoti kvadratinių funkcijų $y = f(x)$ grafikai.
# <img src="../images/2025b1_7.png" width="250"/>
# Kuriuose paveiksluose pavaizduota tokia funkcija $y=f(x)$, kad lygtis $f(x)=0$ turi bent vieną neigiamą sprendinį?  (**1 tšk.**)
#
# 8\. Duotas reiškinys $\dfrac{9-x^2}{x+3}$
# * Parink teisingą reiškinio apibrėžimo sritį (**1 tšk.**)
# $\begin{array}{l{\quad}l}
# \boxed{A}\, (-\infty,+\infty) &
# \boxed{B}\, x=-3 \\
# \boxed{C}\, (-\infty,9) \bigcup (9,+\infty) &
# \boxed{D}\, (-\infty,-3) \bigcup (-3,+\infty)
# \end{array}$
# * Suprastink reiškinį $\dfrac{9-x^2}{x+3}$ (**1 tšk.**)
#
# 9\. Duota funkcijos $f(x) = -2x^2 - 2x + 2$.
# * Užrašyk šios funkcijos reikšmių didėjimo intervalą (**1 tšk.**)
# * Apskaičiuok šios funkcijos didžiausią reikšmę (**1 tšk.**)
#
# 10\. Žinoma sekos $(a_n)$ $n$-tojo nario formulė $a_n=4n+2$.
# * Apskaičiuok: $a_4-a_2$ (**1 tšk.**)
# * Kuri rekurentinė formulė tinkama šiai sekai aprašyti? (**1 tšk.**)
# $\begin{array}{l}
# \boxed{A}\, a_{n+1}=a_n + 4,\,a_1=6 \\
# \boxed{B}\, a_{n+1}=a_n - 2,\,a_1=6 \\
# \boxed{C}\, a_{n+1}=a_n - 4,\,a_1=5 \\
# \boxed{D}\, a_{n+1}=a_n + 4,\,a_1=5
# \end{array}$
#
# 11\. Stačiakampio $ABCD$ plotis lygus kvadrato $KLMN$ kraštinei, o ilgis $4\,\text{cm}$ didesnis už plotį. Koks šio stačiakampio ilgis ir plotis, jei stačiakampio plotas $7\,\text{cm}^2$ didesnis už kvadrato plotą?
# Stačiakampio plotį pažymime $x$, ilgį $y$. Kuri lygčių sistema tinkama šiam uždaviniui išspręsti? (**1 tšk.**)
# $\begin{array}{l{\quad}l}
# \boxed{A}\, \begin{cases} xy + 7 = x^2 \\ x-y=4\end{cases} &
# \boxed{B}\, \begin{cases} xy + 7 = x^2 \\ y-x=4\end{cases} \\
# \boxed{C}\, \begin{cases} xy - 7 = x^2 \\ y-x=4\end{cases} &
# \boxed{D}\, \begin{cases} xy - 7 = x^2 \\ x-y=4\end{cases}
# \end{array}$
#
# 12\. Jokūbas keliauja iš miesto $A$ į miestą $C$. Atstumas tarp $A$ ir $C$ yra $250\,\text{km}$. Pirmuosius $12\%$ kelio, iki miestelio
# $B$, Jokūbas važiavo $x\,\text{km/h}$ greičiu. Likusią kelio dalį jis greitį padidino $20\,\text{km/h}$.
# * Koks atstumas tarp $B$ ir $C$  (**1 tšk.**)
# * Kuris reiškinys tinka visoje kelionėje sugaištam laikui apskaičiuoti? (**1 tšk.**)
# $\begin{array}{l}
# \boxed{A}\, 30\cdot x + 220\cdot (x+20) \\
# \boxed{B}\, 220\cdot x + 30\cdot (x+20) \\
# \boxed{C}\, \dfrac{30}{x} + \dfrac{220}{x+20} \\
# \boxed{D}\, \dfrac{220}{x} + \dfrac{30}{x+20}
# \end{array}$
#
# 13\. Apie kvadratą $ABCD$ apibrėžtas apskritimas. Kvadrato kraštinės ilgis lygus $12$. Apskaičiuok nuspalvintos figūros plotą.  (**1 tšk.**)
# <img src="../images/2025b1_13.png" width="120"/>
# $\begin{array}{l{\quad}l}
# \boxed{A}\, 288\pi - 144 &
# \boxed{B}\, 72\pi - 144 \\
# \boxed{C}\, 18\pi - 36 &
# \boxed{D}\, 72\pi - 36
# \end{array}$
#
# 14\. Tomas pardavinėja marškinėlius. Jei jis parduoda marškinėlius po $40$ eurų už vienetą, per mėnesį jam pavyksta parduoti $120$ marškinėlių. Kainos sumažinimas $1$ euru, parduotų marškinėlių kiekį padidina $5$ vienetais. Tomas nusprendė sumažinti marškinėlių kainą $x$ eurų.
# * Užrašyk reiškinį Tomo pajamoms $P(x)$ apskaičiuoti. (**1 tšk.**)
# * Kokia turi būti marškinėlių kaina, kad pajamos būtų didžiausios? (**1 tšk.**)
#
# 15\. Nubrėžtas tiesės $y=kx+b$ grafikas. Tiesė eina per taškus $(0; 4)$ ir $(1; 0)$.  Apskaičiuok krypties koeficiento $k$ ir postūmio koeficiento $b$ reikšmes.  (**2 tšk.**)
# <img src="../images/2025b1_15.png" width="240"/>
#
# 16\. Nubrėžtas vienetinis apskritimas ir jame pažymėti posūkio kampai $\alpha$ ir $\beta$. Žinome, kad $\cos \alpha = 0{,}8$. Pagal brėžinio duomenis apskaičiuok $\cos \alpha$ ir $\sin \beta$ (**2 tšk.**)
# <img src="../images/2025b1_16.png" width="240"/>
#
# 17\. Apie apskritimą apibrėžtas keturkampis $ABCD$, kurio  kraštinių ilgiai yra $AB=11$, $BC=10$, $CD=14$. Apskaičiuok kraštinės $AD$ ilgį. (**1 tšk.**)
# <img src="../images/2025b1_17.png" width="120"/>
#
# 18\. Apskritimo skersmuo $CD$ statmenas stygai $AB$. Apskaičiuok atstumą nuo apskritimo centro iki stygos $AB$, jei apskritimo spindulys $R=25\,\text{cm}$, o stygos $AB$ ilgis lygus $40\,\text{cm}$.  (**1 tšk.**)
# <img src="../images/2025b1_18.png" width="150"/>
#
# 19\. Paulius nusprendė išmatuoti ežero plotį. Skirtinguose ežero krantuose jis pasirinko taškus $A$ ir $B$ ir išmatavo atstumus nuo taško $O$ iki šių taškų. Paaiškėjo, kad $OA=75\,\text{m}$, $OB=105\,\text{m}$. Tada jis pratęsė tiesę $AO$ ir tašką $C$ pažymėjo taip, kad $OC=5\,\text{m}$. Pratęsęs tiesę $BO$, tašką $D$ pažymėjo taip, kad $OD=7\,\text{m}$. Koks ežero plotis, jei Paulius išmatavo, kad $CD=11\,\text{m}?$  (**1 tšk.**)
# <img src="../images/2025b1_19.png" width="250"/>
#
# 20\. Tyrimo metu apklausta $14$ moksleivių ir jų ūgio bei svorio duomenys pavaizduoti sklaidos diagrama. Kiek tyrime dalyvavo moksleivių, kurių ūgis nedidesnis nei $170\,\text{cm}$, o svoris mažesnis nei $60\,\text{kg}$?  (**1 tšk.**)
# <img src="../images/2025b1_20.png" width="350"/>
#
# 21\. Į lygiašonį trikampį $ABC$ įbrėžtas apskritimas liečia trikampio kraštines taškuose $K$, $L$ ir $M$. Apskaičiuok $\angle BAC$ didumą, jei $\angle OBC = 14^\circ$.  (**1 tšk.**)
# <img src="../images/2025b1_21.png" width="120"/>
#
# 22\. Lygiakraštis trikampis $ABC$ įbrėžtas į apskritimą. Apskaičiuok nuspalvintos figūros plotą, jei apskritimo spindulys $r=2\,\text{cm}$.  (**1 tšk.**)
# <img src="../images/2025b1_22.png" width="120"/>
#
# 23\. Trikampio $ABC$ pusiaukraštinės $AE$ ir $BF$ kertasi taške $O$. Trikampio $EFO$ plotas lygus $18\,\text{cm}^2$. Apskaičiuok trikampio $AOB$ plotą. (**1 tšk.**)
# <img src="../images/2025b1_23.png" width="150"/>
#
# 24\. Žinomi šie trikampio $ABC$ dydžiai: $b=17\,\text{cm}$, $\alpha = 41^\circ$, $\beta = 47^\circ$. Apskaičiuok kraštinės $CB$ ilgį dešimtųjų tikslumu. (**1 tšk.**)
# <img src="../images/2025b1_24.png" width="150"/>
#
# 25\. Išskaidyk trinarį $2x^2-5x+2$ daugikliais  (**1 tšk.**)
#
# 26\. Apie trikampį $ABC$ žinoma: $AC=7$, $CB=8$, $\angle ACB = 60^\circ$.
# <img src="../images/2025b1_26.png" width="150"/>
# * Apskaičiuok trikampio plotą $S$ (**1 tšk.**, su sprendimu)
# * Apskaičiuok kraštinės $AB$ ilgį (**1 tšk.**, su sprendimu)
# * Apskaičiuok aukštinės $AH$ ilgį (**1 tšk.**, su sprendimu)
#
# 27\. Išspręsk lygčių sistemą $\begin{cases} x-y = -13 \\ y^2-x=69 \end{cases}$ (**3 tšk.**, su sprendimu)
#
# 28\. Suprastink reiškinį $\dfrac{8}{x-8} - \dfrac{x^2-x}{x-8} \cdot \dfrac{1}{x-1}$ (**3 tšk.**, su sprendimu)
#
# 29\. Trapecija $ABCD$ įbrėžta į apskritimą. Įrodyk kad ji lygiašonė  (**3 tšk.**, su sprendimu)
# <img src="../images/2025b1_29.png" width="150"/>
#
# 30\. Jei tiesė $y=kx-5$ liečia parabolę $y= -2x^2+5x-7$, tai $k=9$ arba $k=1$. Įrodyk (**3 tšk.**, su sprendimu)
