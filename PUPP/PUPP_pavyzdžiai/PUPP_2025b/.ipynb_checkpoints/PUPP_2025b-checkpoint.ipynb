# %% [markdown]
# [Formulynas](../../formulynas.png)

# %% [markdown]
# ## PUPP bandomasis 2025
# * Patikrinimą sudaro 31 uždavinys.
# * Patikrinimo taškų suma yra 50 taškų.
# * Patikrinimo trukmė – 150 min.
# * Šaltinis: [BETA ITS](https://beta.etestavimas.lt/tests/view/bc0e5412490a/569)
#
#
# 1\. Sekos $(a_n)$ $n$-tojo nario formulė yra $a_n = 2n – 1$. Apskaičiuokite šios sekos trečiąjį narį $a_3$. (**1 tšk.**)
#
# 2\. Pažymėkite paveikslą, kuriame pavaizduotas funkcijos $y = –x^2$ grafikas. (**1 tšk.**)
# <img src="../images/2025b_2.png" width="500"/>
#
# 3\. Duota kvadratinė lygtis $x^2 – 12x + 27 = 0$.
# * Naudodamiesi kvadratinės lygties diskriminanto formule, parodykite, kad šios lygties diskriminantas $D$ lygus $36$. (**1 tšk.** su sprendimu)
# * Naudodamiesi kvadratinės lygties sprendinių formulėmis, apskaičiuokite šios lygties sprendinius.  (**2 tšk.**)
#
# 4\. Nustatykite, kuri skaičių pora yra vienas iš lygčių sistemos $\begin{cases} x-y=3\\xy=18 \end{cases}$ sprendinių. (**1 tšk.**)
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, (6;\,3) &
# \boxed{B}\, (5;\,2) &
# \boxed{C}\, (3;\,6) &
# \boxed{D}\, (2;\,5)
# \end{array}$
#
# 5\. Paveiksle pavaizduotas funkcijos $y=f(x)$ grafikas, kai $x\in [5;\,6]$. Naudodamiesi grafike pateiktais duomenimis, atlikite užduotis.
# <img src="../images/2025b_5.png" width="250"/>
# * Raskite $f(-1)$ reikšmę. (**1 tšk.**)
# * Nustatykite, su kuria $x$ reikšme $f(x) = -3$ (**1 tšk.**)
# * Užrašykite didžiausią funkcijos $y=f(x)$ reikšmę (**1 tšk.**)
#
# 6\. Nustatykite, su kuria $x$ reikšme reiškinys $\dfrac{2-x}{x-1}$ neturi prasmės.  (**1 tšk.**)
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, 2 &
# \boxed{B}\, 1 &
# \boxed{C}\, 0 &
# \boxed{D}\, -1
# \end{array}$
#
# 7\. 1 paveiksle pavaizduoto trikampio plotas $S=\dfrac{1}{2}ab\cdot\sin\angle C$.
# Naudodamiesi 2 paveiksle pateiktais duomenimis, apskaičiuokite jame pavaizduoto trikampio plotą. (**1 tšk.**)
# <img src="../images/2025b_7_1.png" width="100"/><img src="../images/2025b_7_2.png" width="100"/>
#
# 8\. Paveiksle pavaizduoto apskritimo centras yra taškas $O$. Taškai $A$, $B$ ir $C$ priklauso apskritimui. Nuspalvinto apskritimo lanko $AC$ didumas yra $160^\circ$. Nustatykite kampų $α$ ir $β$ didumus. (**2 tšk.**)
# <img src="../images/2025b_8.png" width="120"/>
#
# 9\. Nustatykite smailiojo kampo $A$ didumą, jei $\cos\angle A = 0{,}5$ (**1 tšk.**)
#
# 10\. Paveiksle pavaizduoti keturkampiai $ABCD$ ir $A_1B_1C_1D_1$ yra panašieji. Keturkampio $A_1B_1C_1D_1$ ilgiausios kraštinės $A_1D_1$ ilgis lygus $18$. Naudodamiesi paveiksle pateiktais duomenimis, atlikite užduotis.
# <img src="../images/2025b_10.png" width="300"/>
# * Kiek kartų keturkampio $A_1B_1C_1D_1$ kraštinės ilgesnės už atitinkamas keturkampio $ABCD$ kraštines? (**1 tšk.**)
# * Keturkampio $ABCD$ perimetras yra $23$. Apskaičiuokite keturkampio $A_1B_1C_1D_1$ perimetrą. (**1 tšk.**)
#
# 11\. Jonas yra aktyvus savo mokyklos krepšinio komandos „Griaustinis“ aistruolis. Komandoje yra $10$ žaidėjų. Žiemos turnyro finalo rungtynėse „Griaustinis“ susitiko su kitos mokyklos komanda. Stebėdamas finalo rungtynes, Jonas užsirašė, kiek minučių žaidė kiekvienas komandos „Griaustinis“ narys ir kiek taškų jis pelnė. Surinktus duomenis Jonas surašė lentelėje ir pavaizdavo sklaidos diagrama.
# <img src="../images/2025b_11_1.png" width="400"/>
# <img src="../images/2025b_11_2.png" width="550"/>
# Išnagrinėję lentelės ir diagramos duomenis, į lentelės tuščius langelius įrašykite trūkstamus skaičius. (**2 tšk.**)
#
# 12\. Duota nelygybė $(x-5)(x+4)>0$. Ją galima išspręsti įvairiais būdais.
# * Sprendžiant šią nelygybę algebriniu būdu, sudaromos nelygybių sistemos. Kokie palyginimo ženklai turi būti vietoje simbolių $\square$ ir $\diamondsuit$, kad nelygybių sistemos būtų užrašytos teisingai? (**1 tšk.**)
# $\begin{cases}x-5>0\\x+4\,\square\, 0\end{cases}$ arba $\begin{cases}x-5\,\diamondsuit\,0\\x+4<0\end{cases}$
# * Nelygybė $(x-5)(x+4)>0$ yra kvadratinė ir ją galima išspręsti grafiniu būdu.
#   Pažymėkite paveikslą, kuriame pavaizduoti visi šios nelygybės sprendiniai. (**1 tšk.**)
#   <img src="../images/2025b_12.png" width="550"/>
#
# 13\.  Gražina gavo $8000$ eurų palikimą.
# * $3000$ eurų ji padalijo paramos fondams „Keturkojų namai“, „Maži sparneliai“ ir „Žuvelių bičiuliai“ atitinkamai santykiu 3:2:1. Apskaičiuokite, kiek eurų atiteko paramos fondui „Maži sparneliai“. (**1 tšk.**)
# * Likusius 5000 eurų Gražina 3 metams padėjo į banką „Sėkmė“, kuris moka $4\%$ sudėtinių metinių palūkanų. Apskaičiuokite, kokia pinigų suma bus Gražinos „Sėkmės“ banko sąskaitoje po 3 metų. Ats.: $\square$ Eur $\square$ ct (**1 tšk.**)
#
# 14\. Paveiksle pavaizduoto apskritimo centras yra taškas $O$. Tiesės $TS$ ir $TV$ liečia šį apskritimą atitinkamai taškuose $S$ ir $V$. Naudodamiesi paveiksle pateiktais duomenimis, atlikite užduotis.
# <img src="../images/2025b_14.png" width="200"/>
#
# * Parodykite, kad $x = 5$. (**1 tšk.** su sprendimu)
# * Apskaičiuokite atkarpos $OT$ ilgį, jeigu yra žinoma, kad $x = 5$ (**2 tšk.** su sprendimu)
#
# 15\. Suprastinkite reiškinį $\dfrac{2x}{2x-3} - \dfrac{2x+3}{4x-6}$ (**3 tšk.** su sprendimu)
# 16\. Duota tiesinė funkcija $f(x)=3x+b$. Šios funkcijos reikšmė lygi $2$, kai argumento reikšmė lygi $6$. Apskaičiuokite $b$ reikšmę. (**1 tšk.**)
# 17\. Pažymėkite dvi funkcijas, kurių grafiko eskizas galėtų būti paveiksle pavaizduota parabolė. (**2 tšk.**)
# <img src="../images/2025b_17.png" width="200"/>
#
# $\begin{array}{l}
# \boxed{A}\, y=(x+4)(x+8) \\
# \boxed{B}\, y=-(x+8)(x+4) \\
# \boxed{C}\, y=(x-4)(x-8) \\
# \boxed{D}\, y=(x+3)^2-1 \\
# \boxed{E}\, y=(x-3)^2-1 \\
# \boxed{F}\, y=-(x-3)^2-1
# \end{array}$
# 18\. Nustatykite, su kuria teigiama $a$ reikšme lygtis $\dfrac{(x+2)(x-a)}{x-5}=0$ turi tik vieną sprendinį (**1 tšk.**)
#
# 19\. Paveiksle pavaizduotos figūros, sudarytos iš vienodo dydžio kvadratėlių. Šios figūros yra pirmieji trys sekos nariai. Parašykite formulę, pagal kurią būtų galima apskaičiuoti sekos $n$-tojoje figūroje esančių kvadratėlių skaičių $c_n$ (**1 tšk.**)
# <img src="../images/2025b_19.png" width="350"/>
#
# 20\. Inde buvo $4$ litrai $8\%$ druskos tirpalo, gauto druską ištirpinus gėlame vandenyje. Mokinys iš indo išpylė $1$ litrą tirpalo ir įpylė $2$ litrus gėlo vandens. Kiek procentų druskos dabar yra tirpale? (**1 tšk.**)
# 21\. Apie apskritimą, kurio centras yra taškas $O$, apibrėžtas keturkampis $KLMN$, kuris liečia apskritimą taškuose $A$, $B$, $C$ ir $D$. Yra žinoma, kad $LB = 13$, $ND = 6$. Naudodamiesi paveiksle pateiktais duomenimis, apskaičiuokite keturkampio $KLMN$ perimetrą. (**1 tšk.**)
# <img src="../images/2025b_21.png" width="150"/>
#
# 22\. Naudodamiesi brėžinyje pateiktais duomenimis, apskaičiuokite $\cos α + \sin β$ (**1 tšk.**)
# <img src="../images/2025b_22.png" width="150"/>
#
# 23\. Ant languoto popieriaus lapo (visi langeliai yra lygūs kvadratai) Kristupas nubraižė kampą $A$ (žr. pav.). Apskaičiuokite kampo $A$ tangentą (**1 tšk.**)
# <img src="../images/2025b_23.png" width="220"/>
#
# 24\. Naudodamiesi brėžinyje pateiktais duomenimis, apskaičiuokite trikampio $ACK$ plotą, jei $AM = 12$, o $CN = 9$ (**1 tšk.**)
# <img src="../images/2025b_24.png" width="150"/>
#
# 25\. Laivelis, išplaukęs iš uosto $U$, nuplaukė $60\,\text{km}$ vakarų kryptimi į prieplauką $P$ (žr. pav.). Pakeitęs kursą (pasukęs $21^\circ$ į šiaurę), laivelis nuplaukė dar $75\,\text{km}$. Apskaičiuokite, kokiu atstumu kilometrais nuo uosto yra nutolęs laivelis. Pateikite sprendimą ir atsakymą, suapvalintą iki sveikojo skaičiaus (**3 tšk.** su sprendimu)
# <img src="../images/2025b_25.png" width="320"/>
#
# 26\. Trikampio $ABC$ kraštinės $AB$ ilgis $6\,\text{cm}$, o kraštinės $AC$ ilgis $8\,\text{cm}$. $AD$ yra trikampio $ABC$ pusiaukampinė. Apskaičiuokite trikampių $ABC$ ir $ADC$ plotų santykį (**1 tšk.**)
# <img src="../images/2025b_26.png" width="150"/>
#
# 27\. Vakarė $9$ dienas dalyvavo profesiniuose mokymuose. Diagramoje pavaizduota, kiek laiko (valandomis) kiekvieną dieną buvo skirta teorijai mokytis ir kiek praktinei veiklai. Diagramoje nubrėžta tiesė, apie kurią išsidėstę sklaidos diagramos taškai. Kuri iš pateiktų lygčių yra šios tiesės lygtis?
# <img src="../images/2025b_27.png" width="200"/>
# Pažymėkite teisingą atsakymą (**1 tšk.**)
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, y=-0{,}94x + 6{,}8 &
# \boxed{B}\, y=-0{,}94x - 6{,}8 &
# \boxed{C}\, y=0{,}94x + 6{,}8 &
# \boxed{D}\, y=0{,}94x - 6{,}8
# \end{array}$
#
# 28\. Lygties $15x^2 + bx + 7 = 0$ diskriminantas lygus $0$. Kuris teiginys apie nelygybę $15x^2 + bx + 7 > 0$ yra teisingas? (**1 tšk.**)
# * Visi realieji skaičiai yra nelygybės sprendiniai.
# * Nelygybė sprendinių neturi.
# * Tik vienas realusis skaičius yra nelygybės sprendinys.
# * Visi realieji skaičiai, išskyrus vieną skaičių, yra nelygybės sprendiniai.
#
# 29\. Trikampio ABC kraštinių ilgiai yra $6$, $8$ ir $10$. Į šį trikampį įbrėžtas apskritimas, kurio centras yra taškas $O$. Apskaičiuokite įbrėžto apskritimo spindulio ilgį (**1 tšk.**)
#
# 30\. Paveiksle pavaizduoti trikampiai $ABC$ ir $KLM$ yra lygiapločiai ($α < β$). Naudodamiesi paveiksle pateiktais duomenimis, apskaičiuokite $α + β$ (**2 tšk.**)
#
# 31\. Įrodykite, kad parabolės $y=-3x^2+6kx$, kai $k>0$, viršūnės abscisės kvadrato ir viršūnės ordinatės santykis lygus $\dfrac{1}{3}$ (**3 tšk.** su spendimu)
