# %% [markdown]
# ## Natūralieji skaičiai ★★☆
# 1\. Skaičių $42$ mln. $35$ tūkst. $2$ užrašykite skaitmenimis.
# 2\. Duotas skaičius $703402569$. Tegul:
# * $a$ – šio skaičiaus milijonų klasės dešimčių skyriaus skaitmuo,
# * $b$ – šio skaičiaus tūkstančių klasės vienetų skyriaus skaitmuo,
# * $c$ – šio skaičiaus vienetų klasės šimtų skyriaus skaitmuo.
#
# Nurodykite $a+b+c$ reikšmę.
# 3\. Kuriuo atveju skaičius $58020$ teisingai užrašytas jo skaitmenų skyrių suma?
#     $\begin{array}{l{\quad}l{\quad}}
# \boxed{A}\, 5\cdot 10000+8\cdot 1000+2\cdot 100 &
# \boxed{B}\, 5\cdot 10000+8\cdot 1000+2\cdot 10 \\
# \boxed{C}\, 5\cdot 1000+8\cdot 100+2 &
# \boxed{D}\, 58\cdot 1000+ 20
# \end{array}$
# 4\. Apskaičiuokite: $9\cdot 100000+7\cdot 100+4$.
# 5\. Skaičių $14625$ suapvalinkite iki tūkstančių, o skaičių $14843$ suapvalinkite iki šimtų. Kuris teiginys apie gautus skaičius yra teisingas?
# $\begin{array}{l{\quad}l{\quad}}
# \boxed{A}\, \text{Pirmasis skaičius mažesnis už $15000$} &
# \boxed{B}\, \text{Pirmasis skaičius mažesnis už $14800$} \\
# \boxed{C}\, \text{Pirmasis skaičius mažesnis už antrąjį} &
# \boxed{D}\, \text{Pirmasis skaičius didesnis už antrąjį}
# \end{array}$
# 6\. Parašykite didžiausią natūralųjį skaičių, kurį suapvalinus iki dešimčių gautume $1940$.
# 7\. Duoti skaičiai: $147$, $539$, $590$, $660$, $945$, $3348$, $35142$. Kuriame iš pateiktų variantų teisingai pateikti įvardytų požymių dažniai?
# $\begin{array}{|l|l|l|l|l|l|}
# \hline & \text{Dalus iš 2} & \text{Dalus iš 3} & \text{Dalus iš 5} & \text{Dalus iš 9} & \text{Dalus iš 10} \\ \hline
# \text{Variantas }\boxed{A} &4&5&3&2&2 \\ \hline
# \text{Variantas }\boxed{B} &1&0&1&0&2 \\ \hline
# \text{Variantas }\boxed{C} &4&5&1&2&2 \\ \hline
# \text{Variantas }\boxed{D} &1&0&3&1&2 \\ \hline
# \end{array}$
# 8\. Vietoje žvaigždučių įrašykite skaitmenis, jog skaičius $4★8★$ dalintųsi iš $2$, $5$ ir $9$. Atsakyme nurodykite visą skaičių.
# 9\. Raskite skaičiaus $84$ daliklių sumą.
# 10\. Raskite skaičiaus $14$ kartotinių, kurie būtų didesni už $40$, bet mažesni už $200$, skaičių.
# 11\. Kuri skaičių pora turi didžiausią bendrąjį daliklį?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} 40\text{ ir }55 &
# \boxed{B} 12\text{ ir }60 &
# \boxed{C} 36\text{ ir }54 &
# \boxed{D} 27\text{ ir }63
# \end{array}$
# 12\. Raskite skaičių $16$ ir $20$ mažiausią bendrąjį kartotinį.
# 13\. Duoti skaičiai: $1$, $5$, $9$, $10$, $13$, $16$, $18$, $21$, $23$, $31$. Keli iš šių skaičių yra pirminiai ir keli sudėtiniai?
# 14\. Skaičių $252$ išskaidykite pirminiais dauginamaisiais. Apskaičiuokite šių dauginamųjų sumą.
# 15\. Du autobusai išvažiuoja iš tos pačios stotelės tuo pačiu metu skirtingais maršrutais. Pirmasis į tą pačią stotelę grįžta po $30\,\text{min}$, tada stovi joje $10\,\text{min}$ ir vėl kartoja savo maršrutą užtrukdamas tiek pat laiko ir darydamas tokio pat ilgio pertrauką grįžęs. Antrasis autobusas į tą pačią stotelę grįžta po $25\,\text{min}$, tada stovi joje $5\,\text{min}$ ir taip pat vėl kartoja savo maršrutą užtrukdamas tiek pat laiko ir darydamas tokio pat ilgio pertrauką grįžęs. Po kiek minučių autobusai iš pradinės stotelės išvažiuos tuo pačiu metu?
# 16\. Turima $154$ vienos rūšies ir $165$ kitos rūšies saldainių. Šie saldainiai pakuojami į dėžutes taip, kad kiekvienoje jų būtų vienodas vienos ir vienodas kitos rūšies saldainių kiekis. Žinoma, jog pakuojant buvo panaudotas didžiausias įmanomas dėžučių skaičius ir neliko nesupakuotų saldainių. Kiek saldainių yra vienoje dėžutėje?

# %% [markdown]
# ## Trupmeniniai skaičiai ★☆☆
# 1\. Raskite kvadrato plotą vienetų tikslumu, jeigu jo perimetras lygus $6{,}4$.
# 2\. Per 1 minutę bitės sparnai suplasnoja maždaug $12205$ kartus. Kiek kartų suplasnoja bitės sparnai per $1\,\text{s}$? Atsakymą pateikite tūkstantųjų tikslumu.
# 3\. Tomas turėjo $60$ eurų. $\dfrac{2}{5}$ savo pinigų jis išleido parduotuvėje, $\dfrac{2}{3}$ likusių pinigų jis paskolino sesei. Kiek eurų jam liko?
# 4\. Kai Onutė išleido $\dfrac{3}{7}$ visų savo turėtų pinigų, tai jai liko $28$ eurai. Kiek eurų Onutė turėjo iš pradžių?
# 5\. Parduotuvė per mėnesį pardavė $55\%$ turėtų prekių. Kiek prekių parduotuvė turėjo mėnesio pradžioje, jeigu liko neparduota $360$ prekių?
# 6\. Mieste yra $12000$ gyventojų. Į miesto mero rinkimus atėjo $60\%$ miesto gyventojų, iš kurių $75\%$ nubalsavo už vieną kandidatą. Kiek gyventojų nubalsavo už šį kandidatą?
# 7\. Raskite $40\%$ skaičiaus, kurio $80\%$ yra lygu $168$.
# 8\. Kurią valandos dalį sudaro $300\,\text{s}$?
# 9\. Kurią centnerio dalį sudaro $2000\,\text{g}$?
# 10\. Duotos trupmenos: $\dfrac{2}{5}$, $\dfrac{5}{5}$, $\dfrac{7}{6}$, $\dfrac{1}{2}$, $\dfrac{8}{21}$, $\dfrac{7}{8}$, $\dfrac{1}{1}$. Kiek tarp jų yra netaisyklingųjų?
# 11\. Mišrųjį skaičių $\large 2$ $\dfrac{5}{7}$ užrašykite netaisyklingąja trupmena.
# 12\. Netaisyklingąją trupmeną $\dfrac{87}{17}$ užrašykite mišriuoju skaičiumi.

# %% [markdown]
# ## Paprastosios trupmenos ★☆☆
# 1\. Apskaičiuokite $2\dfrac{1}{3}+1\dfrac{1}{3}$
# 2\. Apskaičiuokite $\dfrac{2}{7}+\dfrac{3}{5}$
# 3\. Apskaičiuokite $\dfrac{4}{5}-\dfrac{1}{3}$
# 4\. Apskaičiuokite $2\dfrac{1}{3}-\dfrac{5}{6}$
# 5\. Apskaičiuokite $3\dfrac{1}{2}+2\dfrac{3}{5}$
# 6\. Apskaičiuokite $1\dfrac{2}{3}+\dfrac{1}{2}-\dfrac{4}{5}$
# 7\. Apskaičiuokite $2\dfrac{1}{8}:1\dfrac{1}{4}$
# 8\. Apskaičiuokite $4\dfrac{1}{5}\cdot 1\dfrac{2}{3}$
# 9\. Apskaičiuokite $0:2\dfrac{1}{2}$
# 10\. Apskaičiuokite $2{,}3\cdot \dfrac{5}{46}+\dfrac{3}{4}$
# 11\. Apskaičiuokite $1\dfrac{1}{2}\cdot \dfrac{2}{3}-1\dfrac{1}{4}\cdot \dfrac{4}{5}$
# 12\. Apskaičiuokite $2{,}8-2\dfrac{1}{4}\cdot 1\dfrac{1}{9}$

# %% [markdown]
# ## Lygtys ir nelygybės ★☆☆
# 1\. Išspręskite lygtį $x+1{,}55=2{,}22$
# 2\. Išspręskite lygtį $x-2{,}51=10{,}1$
# 3\. Išspręskite lygtį $8{,}4-x=2{,}55$
# 4\. Išspręskite lygtį $x:0{,}4=10{,}8$
# 5\. Išspręskite lygtį $2{,}5\cdot x+0{,}25=6{,}5$
# 6\. Išspręskite lygtį $8{,}4:x-1{,}5=5{,}5$
# 7\. Išspręskite lygtį $\left(1\dfrac{1}{2}+3\dfrac{1}{4} \right )\cdot x=0$
# 8\. Išspręskite lygtį $x:4\dfrac{2}{5}=2\dfrac{1}{2}$
# 9\. Kiek natūraliųjų sprendinių tenkina nelygybę $x+2{,}1<11$?
# 10\. Kiek natūraliųjų sprendinių tenkina nelygybę $5\cdot x+1\frac{1}{4}<2\frac{1}{5}$?
# 11\. Kvadrato perimetras yra didesnis už $81{,}4$, bet mažesnis už $90{,}4$. Kuris iš duotųjų skaičių galėtų būti šio kvadrato plotas?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} 380{,}25 &
# \boxed{B} 441 &
# \boxed{C} 556{,}96 &
# \boxed{D} 576
# \end{array}$
# 12\. Kiek yra natūraliųjų skaičių, kurie yra didesni negu $104{,}5$, bet mažesni negu $841{,}5$?

# %% [markdown]
# ## Tarpusavyje susiję dydžiai ★★☆
# 1\. Koordinatiniame kampe pažymėtas taškas. Nurodykite jo koordinates.
# <img src="../images/6_5_1.png" width="200"/>
# 2\. Koordinatiniame kampe pradėtas braižyti stačiakampis $ABCD$, kurio perimetras lygus $14$. Pabaikite jį braižyti ir nurodykite viršūnės $D$
#  koordinates.
# <img src="../images/6_5_2.png" width="200"/>
# 3\. Koordinatiniame kampe pažymėtas taškas $(10; 9)$. Nuo šio taško paeinama $4$ vienetus į apačią, vėliau $2$ vienetus į kairę, tada $7$ vienetus į viršų ir $3$ vienetus į dešinę. Kokiame taške dabar esame?
# 4\. Šalia mėlyno stačiakampio tam tikru masteliu pavaizduota žalios spalvos šio stačiakampio kopija. Nurodykite jos mastelį.
# <img src="../images/6_5_4.png" width="200"/>
# 5\. Šalia mėlyno trikampio tam tikru masteliu pavaizduota žalios spalvos šio trikampio kopija. Nurodykite jos mastelį.
# <img src="../images/6_5_5.png" width="200"/>
# 6\. Šalia mėlyno trikampio pavaizduoti keturi žali, iš kurių tik vienas yra teisingai tam tikru masteliu pavaizduota mėlyno trikampio kopija. Nurodykite jos mastelį.
# <img src="../images/6_5_6.png" width="200"/>
# 7\. Lukas žemėlapyje, kurio mastelis nurodytas $1:1500000$, išmatavo atstumą tarp miestų ir gavo $6{,}4\,\text{cm}$. Vėliau pagal mastelį jis apskaičiavo realų atstumą tarp miestų. Kiek kilometrų jis gavo?
# 8\. Per gamtos pažinimo pamoką Skaistė nupiešė vabzdžio, kurio realus ilgis $15\,\text{mm}$, padidintą vaizdą. Kokiu masteliu mergaitė nupiešė vabzdį, jei piešinyje vabzdžio ilgis $6\,\text{cm}$?
# 9\. Norėdamas apskaičiuoti namo, kuriame gyvena Tadas, aukštį jis sugalvojo save nufotograguoti šalia jo. Po to berniukas išsimatavo savo tikrą ūgį, o tada nuotraukoje. Gauti rezultatai buvo $1\,\text{m}\,40\,\text{cm}$ ir $4\,\text{cm}$. Galiausiai Tadas išmatavo namo aukštį nuotraukoje ir gavo $12\,\text{cm}$. Vėliau atlikus reikalingus skaičiavimus berniukas surado namo aukštį tikrovėje. Kokį atsakymą metrais jis gavo?
# <img src="../images/6_5_9.png" width="300"/>
# 10\. Perkant $4$ vienodus rašiklius sumokama $2{,}4$ euro. Kiek kainuos $10$ tokių rašiklių?
# 11\. $250\,\text{g}$ braškių parduotuvėje kainuoja $1{,}6$ euro. Kiek gramų braškių galima nusipirkti už $8$ eurus?
# 12\. Trys dviratininkai važiuoja keliu. Pirmasis per $2\dfrac{2}{3}$ valandos nuvažiavo $48\,\text{km}$, antrasis per $\dfrac{3}{5}$ valandos nuvažiavo $10{,}2\,\text{km}$, o trečiasis per $3{,}2$ valandos nuvažiavo $57{,}6\,\text{km}$. Raskite visų dviratininkų greičius.
# 13\. Buvo atliekamas eksperimentas. Ant spyruoklės kaskart buvo kabinamas skirtingos masės svarelis ir žiūrima, kiek pailgės spyruoklė. Gauti rezultatai buvo pavaizduoti grafiku:
# <img src="../images/6_5_13.png" width="200"/>
# * Kiek centimetrų išsitempia spyruoklė prie jos prikabinus $300\,\text{g}$ svarelį?
# * Kiek gramų sveriantį svarelį reikia prikabinti norint, jog spyruoklė pailgėtų $18\,\text{cm}$?
#
# 14\. Žemiau pavaizduotos dvi lentelės, kuriose pateiktos tarpusavyje susijusių dydžių $x$ ir $y$ reikšmės. Tik vienoje lentelėje dydžiai yra tiesiogiai proporcingi. Nustatykite tą lentelę, kurioje dydžiai yra tiesiogiai proporcingi ir baikite ją pildyti.
#
# $\begin{array}{l{\quad}l}
# \begin{array}{|c||c|c|c|c|} \hline
# x & 5 & 8 & 10 & \\ \hline
# y & 6 & & 12 & 4{,}8 \\ \hline
# \end{array} &
# \begin{array}{|c||c|c|c|c|} \hline
# x & 3 & 6 & 9 & \\ \hline
# y & 4 & & 10 & 13 \\ \hline
# \end{array}
# \end{array}$
#
# 15\.Ritos, jos draugės Gretos namai ir parduotuvė yra vietovėse, kurias jungia keliai, sudarantys lygiakraštį trikampį (žiūrėti paveikslėlį). Mergaitės tuo pačiu metu išeina iš savo namų parduotuvės link. Rita eina $4\,\text{km/h}$ greičiu, o Greta $6\,\text{km/h}$ greičiu. Kiek minučių pirma į parduotuvę atėjusi Greta lauks savo draugės, jei žinoma, jog mergaičių namus skiria $480\,\text{m}$ atstumas?
#
# <img src="../images/6_5_15.png" width="200"/>

# %% [markdown]
# ## Plokštumos figūros ★★☆
# 1\. Apskaičiuokite $\angle 1$ dydį laipsniais, kai žinoma, jog $\angle 2 = 30^{\circ}$
# <img src="../images/6_6_1.png" width="200"/>
# 2\. Kuris iš žemiau nurodytų dydžių yra didžiausias?
# $\begin{array}{l{\quad}l}
# \boxed{A} 0{,}3\,\text{ištiestinio kampo} &
# \boxed{B} 50\% \,\text{stačiojo kampo} \\
# \boxed{C} \dfrac{1}{7}\,\text{kampo, kurio didumas}\,280^{\circ}&
# \boxed{D} 10\%\,\text{pilnojo kampo}&
# \end{array}$
# 3\. Nurodykite trikampio rūšį, kai žinoma, jog jo perimetras lygus $20\,\text{cm}$, o dviejų kraštinių ilgiai yra $6\,\text{cm}$ ir $7\,\text{cm}$.
# $\begin{array}{l{\quad}l}
# \boxed{A} \text{Įvairiakraštis} &
# \boxed{B} \text{Lygiašonis} \\
# \boxed{C} \text{Lygiakraštis}&
# \boxed{D} \text{Trikampio rūšies nustatyti neįmanoma}
# \end{array}$
# 4\. Lygiakraščio trikampio kraštinė lygi $6\dfrac{2}{3}$. Apskaičiuokite šio trikampio perimetrą.
# 5\. Nurodykite trikampio rūšį, kai žinoma, jog jo dviejų kampų didumai yra $20^\circ$ ir $69^\circ$.
# $\begin{array}{l{\quad}l}
# \boxed{A} \text{Smailusis} &
# \boxed{B} \text{Bukasis} \\
# \boxed{C} \text{Statusis}&
# \boxed{D} \text{Trikampio rūšies nustatyti neįmanoma}
# \end{array}$
# 6\. Smailiojo trikampio vienas kampas lygus $37^\circ$. Kuri reikšmė negali būti šio trikampio vieno iš likusių kampų didumas?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} 63^\circ &
# \boxed{B} 89^\circ &
# \boxed{C} 70^\circ &
# \boxed{D} 50^\circ
# \end{array}$
# 7\. Stačiojo trikampio vienas kampas lygus $23^\circ$. Raskite nežinomo kampo didumą laipsniais.
# 8\. Pagal pateiktus duomenis apskaičiuokite pavaizduoto trikampio plotą. Rezultatą išreikškite dešimtaine trupmena.
# <img src="../images/6_6_8.png" width="250"/>
# 9\. Žemiau pavaizduoti $4$ keturkampiai. Apskaičiuokite jų perimetrus centimetrais.
# <img src="../images/6_6_9.png" width="250"/>
# 10\. Iš $48\,\text{cm}$ vielos buvo išlankstytas stačiakampis, kurio ilgis lygus $8\,\text{cm}$. Apskaičiuokite šio stačiakampio plotą.
# 11\. Iš tam tikro ilgio vielos buvo išlankstytas stačiakampis, kurio ilgis $8\dfrac{2}{7}\,\text{cm}$, o plotis – $11\dfrac{5}{7}\,\text{cm}$. Vėliau iš tos pačios vielos išlankstytas kvadratas. Apskaičiuokite jo plotą.
# 12\. Taisyklingojo šešiakampio perimetras lygus $73{,}8$. Apskaičiuokite jo kraštinės ilgį.
# 13\. Kiek iš vienos septyniakampio viršūnės galima nubrėžti įstrižainių?
# 14\. Apskaičiuokite dešimtkampio kampų sumą laipsniais.
# 15\. Apskaičiuokite pavaizduoto penkiakampio plotą kvadratiniais centimetrais, padalindami šį daugiakampį į mažesnes figūras.
# <img src="../images/6_6_15.png" width="300"/>
# 16\. Apskritimo spindulio ilgis lygus $8$. Naudodami $\pi \approx 3{,}14$ reikšmę raskite apskritimo ilgį ir ribojamą plotą.
# 17\. Dviejų apskritimų, kurių skersmenų ilgiai yra $12\,\text{cm}$ ir $20\,\text{cm}$ centrus jungia atkarpa, kurios ilgis $10\,\text{cm}$. Šios atkarpos viduryje pažymėtas taškas. Kuris teiginys apie šio taško padėtį apskritimų atžvilgiu yra teisingas?
# $\begin{array}{l}
# \boxed{A} \text{Taškas yra abiejų apskritimų išorėje} \\
# \boxed{B} \text{Taškas yra didesniojo apskritimo viduje, o mažesnio išorėje} \\
# \boxed{C} \text{Taškas yra mažesniojo apskritimo viduje, o didesnio išorėje} \\
# \boxed{D} \text{Taškas yra abiejų apskritimų viduje}
# \end{array}$

# %% [markdown]
# ## Erdviniai kūnai ★★☆
# 1\. Suskaičiuokite, kiek iš pavaizduotų erdvinių kūnų yra briaunainių.
# <img src="../images/6_7_1.png" width="250"/>
# 2\. Žemiau pavaizduotas stačiakampis gretasienis. Apskaičiuokite jo viršūnių skaičių, sienų skaičių ir briaunų skaičių.
# <img src="../images/6_7_2.png" width="150"/>
# 3\. Kubo vienos sienos plotas lygus $3{,}5$. Koks šio kubo viso paviršiaus plotas?
# 4\. Kaip vadinama ši piramidė?
# <img src="../images/6_7_4.png" width="100"/>
# $\begin{array}{ll}
# \boxed{A} \text{Trikampė piramidė} &
# \boxed{B} \text{Keturkampė piramidė} \\
# \boxed{C} \text{Penkiakampė piramidė} &
# \boxed{D} \text{Šešiakampė piramidė}
# \end{array}$
# 5\. Žemiau pavaizduota piramidė. Apskaičiuokite jos viršūnių skaičių, sienų skaičių ir briaunų skaičių.
# <img src="../images/6_7_5.png" width="100"/>
# 6\. Piramidė turi $12$ briaunų. Apskaičiuokite jos viršūnių skaičių ir sienų skaičių.
# 7\. Iš vielos išlankstytas kubas, kurio briaunos ilgis lygus $3$. Vėliau iš to paties ilgio vielos išlankstyta trikampė piramidė, kurios visos briaunos lygios. Raskite vienos jų ilgį.
# 8\. Apskaičiuokite duotosios stačiosios trikampės prizmės pagrindo plotą ir šoninio paviršiaus plotą.
# <img src="../images/6_7_8.png" width="150"/>
# 9\. Žemiau pateikta stačiosios prizmės išklotinė. Pagal pateiktus duomenis apskaičiuokite jos šoninio paviršiaus plotą.
# <img src="../images/6_7_9.png" width="200"/>
# 10\. Duota stačioji prizmė. Ji turi $14$ viršūnių. Kiek ši prizmė turi sienų ir kiek turi briaunų?
# 11\. Turime du stačiakampius gretasienius. Vieno jų duota išklotinė, o kito - erdvinio vaizdo brėžinys. Pagal pateiktus duomenis apskaičiuokite, kiek vieno stačiakampio gretasienio viso paviršiaus plotas didesnis už kito.
# <img src="../images/6_7_11.png" width="300"/>
# 12\. Duota stačiosios prizmės išklotinė. Apskaičiuokite šios prizmės šoninio paviršiaus plotą.
# <img src="../images/6_7_12.png" width="200"/>

# %% [markdown]
# ## Tūris ir jo matavimo vienetai ★★☆
# 1\. Kubo briaunos ilgis $20\,\text{cm}$. Kuris iš atsakymų yra šio kubo tūris?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} 8\,\text{dm}^3 &
# \boxed{B} 800\,\text{cm}^3 &
# \boxed{C} 0{,}8\,\text{dm}^3 &
# \boxed{D} 0{,}08\,\text{m}^3
# \end{array}$
# 2\. Stačiakampio gretasienio matmenys yra $80\,\text{cm } \times 4\,\text{dm } \times 300\,\text{mm}$. Kam lygus jo tūris?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} 9600\,\text{mm}^3 &
# \boxed{B} 9{,}6\,\text{m}^3 &
# \boxed{C} 960\,\text{cm}^3 &
# \boxed{D} 96\,\text{dm}^3
# \end{array}$
# 3\. Kubo paviršiaus plotas lygus $150\,\text{cm}^2$. Kam lygus šio kubo tūris?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} 125\,\text{cm}^3 &
# \boxed{B} 175\,\text{cm}^3 &
# \boxed{C} 225\,\text{cm}^3 &
# \boxed{D} 675\,\text{cm}^3
# \end{array}$
# 4\. Stačiakampio gretasienio ilgis yra $3$ kartus didesnis už aukštį, o plotis yra $5$ vienetais trumpesnis už aukštį. Raskite šio stačiakampio gretasienio tūrį, jeigu jo aukštis yra lygus $10$.
# 5\. Kubo visų briaunų ilgių suma lygi $48\,\text{cm}$. Kam lygus šio kubo tūris?
# 6\. Jeigu kubo briaunos ilgį padidinsime $3$ kartus, kiek kartų padidės šio kubo tūris?
# 7\. Turime stačiakampį gretasienį, kurio plotis yra lygus $8$, o aukštis - $10$. Taip pat turime ir kubą, kurio briaunos ilgis yra lygus $10$. Raskite stačiakampio gretasienio ilgį, jeigu yra žinoma, kad kubo tūris yra lygus pusei stačiakampio gretasienio tūrio.
# 8\. $12700\,\text{cm}^3$ paverskite kubiniais metrais.
# 9\. $7{,}5\,\text{m}^3$ paverskite litrais.
# 10\. Kas turi būti parašyta kvadratėlio vietoje, kad lygybė $0{,}012\,\text{dm}^3 + \square\,\text{mm}^3 = 15\,\text{cm}^3$ būtų teisinga?
# 11\. Turime $0{,}5\,\text{m}^3$ sulčių, kurias reikės išpilstyti į $200\,\text{ml}$ indelius. Kiek indelių gausime?
# 12\. Į akvariumą telpa lygiai $24\,\text{l}$ vandens. Koks yra akvariumo aukštis, jeigu jo ilgis yra $40\,\text{cm}$, o plotis - $2\,\text{dm}$?

# %% [markdown]
# ## Duomenys ir rinkiniai ★★☆
#
# 1\. Mokykloje vienos klasės mokiniai buvo apklausti, koks mokomasis dalykas jiems labiausiai patinka. Visi mokiniai nurodė po vieną mėgstamą dalyką. Gauti atsakymų rezultatai buvo pavaizduoti stulpeline diagrama.
# <img src="../images/6_9_1.png" width="300"/>
# * Kiek mokinių buvo apklausta?
# * Kiek mokinių daugiau mėgsta kūno kultūrą nei lietuvių kalbą?
# * Kuri dalis visų apklaustų mokinių mėgsta gamtos pažinimą?
#
# 2\. Lentele pateikta duomenų apie $2016\,\text{m}$. Baltijos valstybėse susidariusių atliekų kiekius vienam gyventojui kilogramais (skaičiai suapvalinti iki tūkstančių) statistika.
# $\begin{array}{|c|c|c|} \hline   \textrm{Valstybė} & \textrm{Lietuva} & \textrm{Latvija} & \textrm{Estija}\\\hline  \textrm{Atliekos 1 gyventojui} & 2000 & 1000 & 18000\\\hline \end{array}$
# Šiuos duomenis pavaizduokite stulpeline diagrama. Vienos padalos vertė yra $1000\,\text{kg}$, o ją atitinkančios atkarpos ilgis $0{,}5\,\text{cm}$ (žiūrėti paveikslėlį).
# <img src="../images/6_9_2.png" width="300"/>
# * Keliais centimetrais skiriasi Lietuvos atliekų kiekį vaizduojančio stulpelio aukštis nuo Latvijos?
# * Kokio aukščio stulpelį reikės nubrėžti norint pavaizduoti Estijos atliekų kiekį?
# * Keliais centimetrais skiriasi Lietuvos atliekų kiekį vaizduojančio stulpelio aukštis nuo Estijos?
#
# 3\. Stačiakampe diagrama pavaizduota Neptūno planetos atmosferą sudarančių dujų kiekio pasiskirstymas:
# <img src="../images/6_9_3.png" width="200"/>
# * Kiek procentų Neptūno atmosferos sudaro helis?
# * Kiek kubinių metrų vandenilio dujų yra $50\,\text{m}^3$ Neptūno atmosferos?
#
# 4\. Lukas atliko tyrimą, kurio metu apklausė savo klasiokų, kaip dažnai jie lankosi kino teatre. Gautus duomenis jis surašė lentele.
# $\begin{array}{|c|c|c|c|} \hline \textrm{Lankymosi dažnis per mėn.} & \textrm{0} & \textrm{1} & \textrm{2} & \textrm{3}\\\hline   \textrm{Mokinių skaičius} & 5 & 12 & 8 & 5\\\hline \end{array}$
# Vėliau nuspręsta šiuos duomenis pateikti stačiakampe diagrama. Tuo tikslu nubrėžtas $8\,\text{cm}$ ilgio ir $3\,\text{cm}$ pločio stačiakampis, kuris turimiems duomenims pavaizduoti buvo dalijamas į atitinkamus plotelius pagal mokinių skaičių.
# <img src="../images/6_9_4.png" width="250"/>
# Kiek kvadratinių milimetrų ploto atiteks mokiniams, kurie lankosi du kartus per mėnesį?
# 5\. Rokas skrituline diagrama pavaizdavo, kurią dalį paros laiko jis skiria darbui (mokykloje, namie), laisvalaikiui ir miegui.
# <img src="../images/6_9_5.png" width="200"/>
# * Kiek procentų paros Rokas miega?
# * Kiek valandų Rokas skiria darbui?
#
# 6\. Justina stebėjo oro temperatūrą vieną savaitę ir gautus rezultatus pateikė linijine diagrama.
# <img src="../images/6_9_6.png" width="300"/>
# Naudodamiesi pateikta diagrama nurodykite, kuris teiginys yra klaidingas.
# $\begin{array}{l}
# \boxed{A} \text{Žemiausia oro temperatūra buvo sekmadienį} \\
# \boxed{B} \text{Nuo pirmadienio iki trečiadienio oro temperatūra kilo} \\
# \boxed{C} \text{Antradienį ir trečiadienį oro temperatūra buvo skirtinga} \\
# \boxed{D} \text{Žemiausia oro temperatūra siekė }20\,^\circ\text{C},\text{o aukšiausia - }26\,^\circ\text{C}
# \end{array}$
# 7\. Tomas atėjo į restoraną pavalgyti pietų. Jam buvo duotas specialus tos dienos meniu:
# <img src="../images/6_9_7_1.png" width="150"/>
# Jis nori išsirinkti patiekalų porą: vieną iš sriubų ir vieną iš salotų pasirinkimo sąrašo. Žemiau pradėtas braižyti galimybių medis, vaizduojantis galimus Tomo pasirinkimo variantus. Sriubas žymime santrupomis B, V, M (pagal pavadinimo pirmą raidę), o salotas – Š ir C (pagal pavadinimo pirmą raidę).
# <img src="../images/6_9_7_2.png" width="300"/>
# * Į laukelius įrašykite trūkstamus žymėjimus.
# * Baikite braižyti galimybių medį.
# * Nurodykite, kiek iš viso pasirinkimo variantų papietauti turi Tomas.
#
# 8\. Skaistė savo draugei nori padovanoti vieną savo rankų darbo puodelį iš turimų $4$ skirtingų. Šį puodelį Skaistė dar nori papuošti spalvotu lipduku, kurių ji turi $3$ rūšių. Norėdama išsiaiškinti, kiek skirtingų pasirinkimo variantų ji turi, mergaitė nusprendė nubrėžti galimybių medį. Kiekvieną puodelį ji pažymėjo raidėmis $A$, $B$, $C$, $D$, o lipduką skaičiais $1$, $2$, $3$. Žemiau pavaizduotas nepabaigtas braižyti ir pildyti galimybių medis.
# <img src="../images/6_9_8.png" width="300"/>
# * Į laukelius įrašykite trūkstamus žymėjimus.
# * Baikite braižyti galimybių medį.
# * Nurodykite, kiek skirtingų variantų padovanoti puodelį su lipduku turi Skaistė.
#
# 9\. Lukas turi du tetraedro (piramidė, turinti $4$ lygias lygiakraščio trikampio formos sienas) formos žalios ir mėlynos spalvos kauliukus, ant kurių kiekvienos sienos užrašyta po skaičių nuo $1$ iki $4$. Jam kilo mintis išsiaiškinti, kiek yra galimybių gauti skirtingą dviženklį skaičių metant abu šiuos kauliukus, kai žalio kauliuko skaičius yra to dviženklio skaičiaus dešimčių skaitmuo, o mėlyno - vienetų skaitmuo.
# <img src="../images/6_9_9_1.png" width="200"/>
# Tuo tikslu berniukas pradėjo braižyti galimybių lentelę, kurios eskizas pavaizduotas žemiau:
# <img src="../images/6_9_9_2.png" width="300"/>
# Nurodykite, kas turėtų būti įrašyta į $_1\, _2\, _3\, _4$ pažymėtus langelius.
# 10\. Mokykloje į šokių konkursą reikia atrinkti porą, kurią sudarytų berniukas ir mergaitė. Šokių mokytoja gali rinktis iš $2$ berniukų vardu Tadas ir Arnas bei $5$ mergaičių vardu: Eglė, Silvija, Martyna, Indrė ir Kotryna. Pažymėdama kiekvieną mokinį pagal pirmą jo vardo raidę, mokytoja sudarė poros sudarymo galimybių lentelę. Žemiau pavaizduota nebaigta pildyti lentelė:
# <img src="../images/6_9_10.png" width="300"/>
# Nurodykite, kas turėtų būti įrašyta į $_1\, _2\, _3\, _4\, _5$ pažymėtus langelius.

# %% [markdown]
# ## Sveikieji skaičiai ★★☆
# 1\. Koordinačių plokštumoje pažymėtas taškas. Nurodykite jo koordinates.
# <img src="../images/6_10_1.png" width="240"/>
# 2\. Koordinačių plokštumoje pradėtas braižyti stačiakampis $ABCD$, kurio perimetras lygus $18$. Pabaikite jį braižyti ir nurodykite viršūnės $D$ koordinates.
# <img src="../images/6_10_2.png" width="240"/>
# 3\. Duoti skaičiai:
# <img src="../images/6_10_3.png" width="150"/>
# Kiek iš jų yra sveikųjų?
# 4\. Tarp kokių gretimų sveikųjų skaičių yra skaičius $−12{,}4$?
# 5\. Skaičių tiesėje pažymėti taškai, kurių koordinatės yra lygios atitinkamai $a$, $b$, $c$, $d$.
# <img src="../images/6_10_5.png" width="350"/>
# Kuris iš žemiau pateiktų teiginių yra *neteisingas*?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} a>b &
# \boxed{B} c>b &
# \boxed{C} d>0 &
# \boxed{D} b<0
# \end{array}$
# 6\. Tomas sprendė matematikos namų darbų užduotį, kurioje prašė palyginti duotas skaičių poras. Žemiau pateiktas Tomo užduoties sprendimas. Kiek klaidų padarė Tomas?
# <img src="../images/6_10_6.png" width="350"/>
# 7\. Skaičių tiesėje pažymėtas taškas $A(a)$. Ką vadiname $|a|$?
# $\begin{array}{l}
# \boxed{A} \text{Taško}\,A(a)\, \text{nuotolį iki taško}\,B(-a) \\
# \boxed{B} \text{Taško}\,A(a)\, \text{nuotolį iki taško}\,O(0) \\
# \boxed{C} \text{Taško}\,A(a)\, \text{nuotolį iki taško}\,B(\dfrac{a}{2}) \\
# \boxed{D} \text{Nei vienas iš pateiktų atsakymų}
# \end{array}$
# 8\. Iš duotų skaičių išrinkite tuos, kurių moduliai lygūs:
# <img src="../images/6_10_8.png" width="200"/>
# 9\. Kuriuo atveju skaičiai $7{,}5$; $|-2{,}4|$; $-2$; $-3\dfrac{1}{4}$; $\left|-3\dfrac{3}{4}\right|$; $|-2{,}7|$; $|4|$; $\left|1\dfrac{1}{3}\right|$ išrašyti didėjimo tvarka?
# $\begin{array}{l}
# \boxed{A} \left|-3\dfrac{3}{4}\right|; \quad -3\dfrac{1}{4}; \quad |-2{,}7|; \quad|-2{,}4|; \quad -2; \quad \left|1\dfrac{1}{3}\right|; \quad |4|; \quad 7{,}5  \\
# \boxed{B}\quad|4|;\quad -3\dfrac{1}{4}; \quad -2; \quad \left|1\dfrac{1}{3}\right|; \quad |-2{,}4|; \quad|-2{,}7|; \quad \left|-3\dfrac{3}{4}\right|; \quad 7{,}5 \\
# \boxed{C} -3\dfrac{1}{4}; \quad -2; \quad \left|-3\dfrac{3}{4}\right|; \quad |-2{,}7|; \quad|-2{,}4|; \quad \left|1\dfrac{1}{3}\right|; \quad |4|; \quad 7{,}5 \\
# \boxed{D} -3\dfrac{1}{4}; \quad -2; \quad \left|1\dfrac{1}{3}\right|; \quad |-2{,}4|; \quad|-2{,}7|; \quad \left|-3\dfrac{3}{4}\right|; \quad |4|; \quad 7{,}5
# \end{array}$
# 10\. Skaičių tiesėje pažymėti taškai, kurių koordinatės yra lygios atitinkamai $a$, $b$, $d$, $c$
# <img src="../images/6_10_10.png" width="350"/>
# Kuris iš žemiau pateiktų teiginių yra *neteisingas*?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A} |a|=|c| &
# \boxed{B} |b|<|c| &
# \boxed{C} |b|>|a| &
# \boxed{D} |a|>|d|
# \end{array}$
# 11\. Apie skaičių $a$ žinoma, kad jis neigiamas, o jo modulis dviem vienetais didesnis už skaičiaus $7$ modulį. Nurodykite skaičių $a$.
# 12\. Apie skaičių $b$ žinoma, jog jis teigiamas, o jo modulis dviem vienetais mažesnis už skaičiaus $−4$ modulį. Nurodykite skaičių $b$.
# 13\. Stačiojo trikampio $\triangle ABC$, esančio koordinačių plokštumoje, plotas lygus $24$. $AC$ – šio trikampio įžambinė. Žinoma, kad:
# $A(−7;\,−4)$, $B(−1;\,−4)$. Raskite taško $C$ koordinates, jeigu yra žinoma, kad visos trikampio viršūnių koordinatės yra neigiamos.

# %% [markdown]
# ## Šeštos klasės kartojimas ★☆☆
# 1\. Rask skaičių $224$ ir $288$ didžiausias bendrą daliklį
# 2\. Rask skaičių $24$ ir $36$ mažiausią bendrą kartotinį
# 3\. Apskaičiuok $2\,\text{h}\,30\,\text{min}\,45\,\text{s} :3$
# 4\. Apskritimo skersmuo lygus $8$, koks šio apskritimo ilgis? Naudok $\pi \approx 3.14$
# 5\. Kiek natūraliųjų daliklių turi skaičius $72$?
# 6\. Turime kvadratą, kurio kraštinė lygi $4$ cm ir turime statujį trikampį, kurio statiniai lygūs $4\,\text{cm}$ ir $8\,\text{cm}$. Kieno plotas didesnis?
# 7\. Kiek kubelių, kurių briauna lygi $1\,\text{cm}$, tilptų į dėžę, kurios ilgis - $2\,\text{cm}$, plotis - $3\,\text{cm}$, aukštis - $4\,\text{cm}$?
# 8\. Apskaičiuok $-6-4+5-10+15$
# 9\. Apskaičiuok $\frac{1}{7}+\frac{5}{9}$
# 10\. Apskaičiuok $2\frac{5}{6} - 1\frac{3}{4}$
# 11\. Apskaičiuok $\frac{4}{5}:\frac{1}{10}$
# 12\. Apskaičiuok $1 \frac{4}{5} \cdot \frac{5}{6}$
# 13\. Kas daugiau, $\frac{2}{5}$ ar $\frac{4}{9}$
# 14\. Močiutė turi $18$ saldainių, $24$ sausainius ir $30$ apelsinų. Daugiausia keliems vaikams ji gali padalinti savo skanėstus, kad kiekvienas vaikas gautų visko po lygiai?

# %% [markdown]
# ## Šeštos klasės kartojimas ★★☆
#
# 1\. Apskaičiuok ir atsakymą pateik dešimtaine trupmena: $1\frac{4}{5}-1\frac{1}{2}$
# 2\. Suapvalink skaičių $157.455$ iki dešimtųjų.
# 3\. Į kvadratėlį įrašyk skaičių, kurį pakėlęs kvadratu ir pridėjęs $9$ gausi $90$:
#    $□^2+9=90$
# 4\. Turime triženklį skaičių, kuris prasideda skaitmeniu $5$ ir baigiasi skaitmeniu $5$, be to, jis dalijasi iš $9$. Koks yra tas triženklis skaičius?
# 5\. Kuri iš žemiau pateiktų trupmenų yra didžiausia?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l{\quad}}
# \boxed{A}\, \frac{2}{5} &
# \boxed{B}\, \frac{9}{20} &
# \boxed{C}\, \frac{3}{8} &
# \boxed{D}\, \frac{12}{25}
# \end{array}$
# 6\. Laikrodis rodo $21:00$. Kuri paros dalis liko iki vidurnakčio?
# 7\. Turime kubo formos dėžutę, kurios kraštinės ilgis yra $9$. Apskaičiuok dėžutės tūrį.
# 8\. Stalas kainuoja $a$ eurų, o kėdė – $b$ eurų. Ką reiškia užrašas $a−b$?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, \text{Kiek kartų stalas brangesnis už kėdę} &
# \boxed{B}\, \text{Kiek kartų kėdė brangesnė už stalą}\\
# \boxed{C}\, \text{Kiek eurų stalas brangesnis už kėdę} &
# \boxed{D}\, \text{Kiek eurų kėdė brangesnė už stalą}
# \end{array}$
# 9\. Motorinės valties savasis greitis yra $12\,\text{km/h}$, o upės tėkmės greitis yra $4\,\text{km/h}$. Kiek kilometrų Algis nuplauktų valtimi per $3$ valandas pasroviui?
# 10\. Bilietai į teatrą vaikams kainuoja $5\,\text{Eur}$, senjorams – $8\,\text{Eur}$, o visiems kitiems – $12\,\text{Eur}$. Keturių asmenų grupelė perka bilietus kartu. Kuri suma negalėtų susidaryti?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, \text{22 eurai} &
# \boxed{B}\, \text{27 eurai} &
# \boxed{C}\, \text{29 eurai} &
# \boxed{D}\, \text{41 euras}
# \end{array}$
# 11\. Kiek minučių sudaro $\frac{1}{10}$ valandos?
# 12\. Iš 80 kg šviežių vaistažolių gaunama $16\,\text{kg}$ džiovintų. Kiek džiovintų vaistažolių galima gauti iš $45\,\text{kg}$ šviežių?
# 13\. Keturi bebrai pastato užtvanką per $9$ dienas. Keli bebrai pastatytų tokią užtvanką per $3$ dienas?
# 14\. Turguje ūkininkas $50\,\text{g}$ krapų parduoda už $1.20\,\text{Eur}$. Kiek eurų kainuoja $1.5\,\text{kg}$ krapų?

# %% [markdown]
# ## Šeštos klasės kartojimas ★★★
#
# 1\. Apskaičiuok ir atsakymą pateik dešimtaine trupmena. $2\frac{1}{2} − 1\frac{1}{5} + \frac{9}{10}$
# 2\. Suapvalink skaičių $17.9449$ iki šimtųjų.
# 3\. Į kvadratėlį įrašyk tokį skaičių, kad lygybė būtų teisinga: $(□+14)\cdot 3=102$.
# 4\. Turime triženklį skaičių, kuris prasideda skaitmeniu $8$, be to, jis dalijasi ir iš $10$, ir iš $9$. Koks yra tas triženklis skaičius?
# 5\. Kuris skaičius yra nelygybės $41−x<17$ sprendinys?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, 22 &
# \boxed{B}\, 22 &
# \boxed{C}\, 24 &
# \boxed{D}\, 26
# \end{array}$
# 6\. Laikrodis rodo $22:30$. Kuri paros dalis liko iki vidurnakčio?
# 7\. Kubo vienos sienos plotas lygus $49$. Apskaičiuok šio kubo tūrį.
# 8\. Yra žinoma, kad $x−y=75$. Kam tuomet lygu $(x−y):15$?
# 9\. Lenktynėse motociklai išleidžiami į trasą kas $3$ min. Kelintas motociklas bus išleistas į trasą $11\,\text{h}\,15\,\text{min}$, jei lenktynės prasideda $10\,\text{h}\,45\,\text{min}$?
# 10\. Trys darbininkai per $5$ dienas pagamino $75$ detales. Kiek detalių gali pagaminti penki darbininkai per $4$ dienas?
# 11\. $1.2$ valandos paversk minutėmis.
# 12\. Kai sausas molis kuriam laikui pamerkiamas į vandenį, molio masė padidėja $40\%$. Į vandenį buvo pamerkta $8\,\text{kg}$ molio. Apskaičiuok, kokia bus pamerkto molio masė.
# 13\. Mama yra tris kartus vyresnė už savo dukterį, o dukra – du kartus vyresnė už savo brolį. Jų visų trijų metų suma yra $54$ metai. Kiek metų yra broliui?
# 14\. Diana pasikvietė drauges į svečius ir nori jas pavaišinti saldainiais. Jeigu $25$ saldainius ji padalytų po lygiai kiekvienai draugei, tai jai liktų $4$ saldainiai, o jeigu padalytų po lygiai $30$ saldainių, tai jai liktų $2$ saldainiai. Kiek draugių pasikvietė Diana?

# %% [markdown]
# #### In total
# 16 + 12 + 12 + 12 + 15 + 17 + 12 + 12 + 10 + 13 + 14 + 14 + 14 = 173 (13 topics)
