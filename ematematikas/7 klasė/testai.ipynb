# %% [markdown]
# ## Duomenys ★★☆
# 1\. Linos matematikos pažymiai yra: $7$, $10$, $8$, $7$, $6$, $9$, $10$, $5$. Koks Linos matematikos pažymių vidurkis? Atsakymą užrašyk dešimtaine trupmena.
# 2\. Reginos fizikos pažymiai yra: $7$, $9$, $8$, $7$, $7$, $9$, $10$, $8$. Kokia Reginos fizikos pažymių moda?
# 3\. Rimantės chemijos pažymiai yra: $8$, $9$, $7$, $7$, $6$, $9$, $10$, $7$. Kokia Rimantės chemijos pažymių mediana?
# 4\. Lentelėje pateikti Manto geografijos pažymiai.
# $\begin{array} {|c|c|}\hline
# \text{Pažymys} & 5 & 6 & 7 & 8 & 9 & 10 \\
# \hline \text{Dažnis} & 2 & 1 & 5 & 4 & 3 & 1 \\
# \hline  \end{array}$
#    * Kiek pažymių Mantas gavo iš geografijos?
#    * Kurią dalį visų Manto pažymių sudaro devintukai? Atsakymą pateikite dešimtaine trupmena.
#    * Raskite Manto pažymių modą
#    * Raskite Manto pažymių medianą
#    * Raskite Manto geografijos pažymių vidurkį. Atsakymą pateikite dešimtaine trupmena.
#
# 5\. Diagramoje pavaizduoti vienos klasės apklausos duomenys, kokio dydžio batus avi moksleiviai.
#
# <img src="../images/7_1_5.png" width="200"/>
#
#    * Kiek moksleivių mokosi šioje klasėje?
#    * Kurią dalį visų moksleivių sudaro avintys 41 dydžio batus? Atsakymą pateikite dešimtaine trupmena.
#    * Kokia šios klasės moksleivių batų dydžio moda?
#    * Kokia šios klasės moksleivių batų dydžio mediana?
#    * Koks šios klasės moksleivių batų dydžio vidurkis? Atsakymą pateikite dešimtaine trupmena.
#
# 6\. Mantas turi $5$ pažymius iš istorijos. Jo istorijos pažymių vidurkis lygus $7.2$. Mantas parašė eilinį kontrolinį ir gavo devynetą. Koks dabar jo pažymių vidurkis? Atsakymą pateikite dešimtaine trupmena.
# 7\. Patricijos anglų kalbos pažymiai yra: $7$, $9$, $8$, $7$, $□$, $9$, $10$, $7$. Koks Patricijos pažymys slepiasi po kvadratėliu, jeigu yra žinoma, kad visų jos anglų kalbos pažymių vidurkis yra $7.75$?
# 8\. Vienoje darbovietėje dirba $39$ žmonių kolektyvas. Jų amžiaus vidurkis yra lygus $37$. Vienam darbuotojui susirgus, likusių darbuotojų amžiaus vidurkis tapo $36.5$. Kiek metų buvo susirgusiam darbuotojui?
# 9\. Dainiaus istorijos pažymiai yra: $6$, $8$, $8$, $7$, $10$, $9$, $8$, $7$, $6$, $10$. Kokį dar vieną pažymį Dainiui gavus, jo visų istorijos pažymių moda nepasikeistų?
# 10\. Lentelėje pateikti vienos klasės moksleivių per vasarą perskaitytų knygų skaičiaus apklausos duomenys.
# $\begin{array} {|c|c|}\hline \text{Knygų sk.} & 0 & 1 & 2 & 3 & 4 \\
# \hline \text{Dažnis} & ? & 5 & 8 & 3 & 3 \\
# \hline \end{array}$
# Kiek daugiausia moksleivių galėjo neperskaityti nei vienos knygos, kai šios apklausos mediana lygi 2?

# %% [markdown]
# ## Teigiami ir neigiami skaičiai ★★☆
# 1\. Palygink duotas skaičių poras:
# $\begin{array}{l{\quad}l{\quad}l}
# \boxed{A}\, -6\ □ -7 &
# \boxed{B}\, |-5,8| □ -5,8 &
# \boxed{C}\, |4,2| □ |-4,2| \\
# \boxed{D}\, -9.3 □ -9 &
# \boxed{E}\, \left|-1\dfrac{1}{3}\right| □ \dfrac{4}{3} &
# \boxed{F}\, |-7,5| □ \left|-7\dfrac{1}{5}\right| \\
# \boxed{G}\, 2,5 □ 2 \dfrac{3}{5}  &
# \boxed{H}\, |-6,9| □ |-6,5| &
# \boxed{I}\, |0,7| □ \left|-\dfrac{5}{7}\right|
# \end{array}$
#
# 2\. Rask skaičių:
# $\begin{array}{l{\quad}l{\quad}l}
# \boxed{A}\, \text{priešingą skaičiui}\, −3 &
# \boxed{B}\, \text{atvirkštinį skaičiui}\, \frac{2}{7} &
# \boxed{C}\, \text{priešingą skaičiui}\, 5.4 \\
# \boxed{D}\, \text{priešingą skaičiui}\, \frac{1}{7} &
# \boxed{E}\, \text{priešingą skaičiui}\, −1\frac{4}{5} &
# \boxed{F}\, \text{atvirkštinį skaičiui}\, 2.2
# \end{array}$
#
# 3\. Skaičių $4\frac{23}{45}$ užrašyk begaline dešimtaine periodine trupmena.
# 4\. Kuris skaičius didžiausias?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, 0.(43) &
# \boxed{B}\, 0.4(3) &
# \boxed{C}\, 0.43 &
# \boxed{D}\, 0.43(34)
# \end{array}$
# 5\. Suapvalink reikšmę $2.5(72)$ iki tūkstantųjų.
# 6\. Apskaičiuok reiškinio $\left(3 \dfrac{4}{7}\right)^2$ reikšmę.
# 7\. Apskaičiuok reiškinių reikšmes:
# $\begin{array}{l{\quad}l{\quad}}
# \boxed{A}\, −12+17 &
# \boxed{B}\, −9+4,5 &
# \boxed{C}\, 11,2+(−3) \\
# \boxed{D}\, 11,2+(−3) &
# \boxed{E}\, −7+(−12) &
# \boxed{F}\, −1,8+(−4)
# \end{array}$
# 8\. Apskaičiuok reiškinių reikšmes:
# $\begin{array}{l{\quad}l{\quad}}
# \boxed{A}\, 3 - 9 &
# \boxed{B}\, −8.5−5 &
# \boxed{C}\, −10.3−(−18) \\
# \boxed{D}\, 6−(−13) &
# \boxed{E}\, −14−(−3) &
# \boxed{F}\, −1,5−18
# \end{array}$
# 9\. Apskaičiuok reiškinio reikšmę:  $(−2)+(+5)−(−3)+(−8)−(+7)$
# 10\. Apskaičiuok reiškinių reikšmes:
# $\begin{array}{l{\quad}l{\quad}}
# \boxed{A}\, −3 \cdot 7 &
# \boxed{B}\, −2,5 \cdot (−2) &
# \boxed{C}\, −4\cdot (−9) \\
# \boxed{D}\, 6.8:(−4) &
# \boxed{E}\, −10.4:(−26) &
# \boxed{F}\, −135:5
# \end{array}$
# 11\. Apskaičiuok reiškinio reikšmę: $(−16):2\cdot (−5)\cdot 8:(−20)$
# 12\. Apskaičiuok reiškinio reikšmę: $\\-6\cdot 15+86:(18-61)$
# 13\. Palygink reiškinius:
# $-7\cdot (-5)-(12-40)+24:(-4)\quad □ \quad 2\cdot \left(42-(-48):(-6)\right)+4\cdot(-3)$
# 14\. Rask lygčių nežinomųjų, pažymėtų kvadratėliais, reikšmes:
# $\begin{array}{l{\quad}l{\quad}l{\quad}}
# \boxed{A}\, □ \cdot (−5)=65 &
# \boxed{B}\, □:(−8)=−13 &
# \boxed{C}\, 10−□=17 &
# \boxed\, −2+□=18
# \end{array}$

# %% [markdown]
# ## Laipsniai ★☆☆
# 1\. Apskaičiuok: $3^2-2^3-5^2$
# 2\. Apskaičiuok: $2\cdot 3^3-3\cdot 2^2+4\cdot 0.5^2$
# 3\. Apskaičiuok: $(-2)^2-(-3)^3-(-4)^2$
# 4\. Apskaičiuok: $(-2)^3-4\cdot (-3)^2+1$
# 5\. Apskaičiuok: $5\cdot(-2)^4-4\cdot (-2)^2-3\cdot(-2)^3$
# 6\. Apskaičiuok: $(10-7\cdot 5^2):(2^4-5)$
# 7\. Apskaičiuok: $(-2)^3-3^3-(-2)^3-(-3)^2$
# 8\. Apskaičiuok: $(-2^2+3^2)\cdot((-2)^2+3^2)$
# 9\. Apskaičiuok: $(1,2^2+1,6^2):(0,6^2+0,8^2)$
# 10\. Apskaičiuok: $(-1)^1+(-1)^2+(-1)^3+(-1)^4+(-1)^5$
# 11\. Apskaičiuok: $(-2)^1-(-2)^2-(-2)^3-(-2)^4-(-2)^5$
# 12\. Apskaičiuok: $(-7^2+(-2^3)^2):((-2)^5+3^3)$
# 13\. Apskaičiuok: ${\dfrac{2^2}{5}}+\left ( \dfrac{1}{2} \right )^2-2,5^2+{\dfrac{1^2}{5}}+(-1)^{5}$
# 14\. Apskaičiuok: $(-2,1^2+0,41)\cdot((-1,1)^2+0,29)-(-2)^2$

# %% [markdown]
# ## Veiksmai su laipsniais ★★☆
# 1\. Reiškinį $3^{20}:3^5\cdot 3$ užrašyk laipsniu.
# 2\. Reiškinį  $(-2)^{18}:(-2)^9\cdot (-2)^{12}$ užrašyk laipsniu.
# 3\. Reiškinį $4^{45}:4^{40}:4^3$ užrašyk laipsniu, o tada apskaičiuok jo reikšmę.
# 4\. Reiškinį $10^{99}\cdot 1000:10^{9}$ užrašyk laipsniu.
# 5\. Reiškinį $10^{42}\cdot 1000000:10^{45}$ užrašyk laipsniu, o tada apskaičiuok jo reikšmę.
# 6\. Reiškinį $2^{14}\cdot 2^{16}\cdot 3^{30}$ užrašyk laipsniu.
# 7\. Reiškinį $2^{18}\cdot 3^{14}\cdot 2^{12}\cdot 3^{16}$ užrašyk laipsniu.
# 8\. Reiškinį $(5^3)^4:125\cdot 2^9$ užrašyk laipsniu.
# 9\. Reiškinį $(2^{15})^4\cdot2^{35}:(2^3)^{30}$ užrašyk laipsniu, o tada apskaičiuok jo reikšmę.
# 10\. Reiškinį $0,75^{28}:\left (\dfrac{3}{4} \right )^7\cdot 4^{21}$ užrašyk laipsniu.
# 11\. Reiškinį $\left ( 1\dfrac{1}{5} \right )^{17}:0,2^{17}\cdot 6^3$ užrašyk laipsniu.
# 12\. Reiškinį $27^{12}$ užrašyk laipsniu, kurio pagrindas yra 3.
# 13\. Reiškinį $2^{48}$ užrašyk laipsniu, kurio pagrindas yra 16.
# 14\. Reiškinį $25^{32}\cdot 5^{36}:125^{15}$ užrašyk laipsniu.

# %% [markdown]
# ## Reiškiniai ★☆☆
# 1\. Apskaičiuok reiškinio $ab−a^2$ reikšmę, kai $a=7$ ir $b=3$.
# 2\. Stačiakampio ilgis lygus $a$, o plotis $3$ vienetais mažesnis. Nurodyk reiškinį stačiakampio perimetrui apskaičiuoti.
# 3\. Prieš $x$ metų Petrui buvo $y$ metų. Kiek metų bus Petrui po $5$ metų?
# 4\. Suprastink reiškinį $3(4x-2)-2(3x-1)$
# 5\. Suprastink reiškinį $5(2x+y)-4(2y-x)$
# 6\. Suprastink reiškinį $\dfrac{1}{2}(-4x-8y)-\dfrac{1}{4}(-20y-8x)$
# 7\. Atskliausk ir sutrauk panašiuosius dėmenis $(x^{2}-2x-1)-(x^{2}+2x+1)$
# 8\. Apskaičiuok reiškinio $2x(-\dfrac{1}{2}y-4x)-1\dfrac{1}{2}y(2x-8y)$ reikšmę, kai $x=1$ ir $y=1$
# 9\. Sudaryk reiškinį pateiktos figūros perimetrui apskaičiuoti.
# <img src="../images/7_5_9.png" width="200"/>
# 10\. Močiutė turi $x+8$ saldainių, kuriuos nori lygiai padalinti savo $4$ anūkams. Po kiek saldainių gaus kiekvienas iš anūkų?
# 11\. Sausainiai kainuoja $x$ eurų už kilogramą, o saldainių kilogramas $2$ eurais brangesnis. Kiek kainuos pirkinys, kurį sudarys $4\,\text{kg}$ sausainių ir $3\,\text{kg}$ saldainių?
# 12\. Kuris teiginys teisingas, jei $x=4\dfrac{1}{2}$ ir $y=2\dfrac{1}{2}$:
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, x\cdot y > 11\frac{1}{2} &
# \boxed{B}\, x - y - 1<0 &
# \boxed{C}\, x:y>2 &
# \boxed{D}\, y:x>\frac{1}{2}
# \end{array}$
# 13\. Suprastink reiškinį $-2x-(-x)+(-2x)-x-2\cdot (-x)$
# 14\. Pavaizduoto paveikslėlyje trikampio perimetras užrašomas kaip $P=9x−10$. Kam yra lygi nežinoma trikampio kraštinė?
# <img src="../images/7_5_14.png" width="200"/>

# %% [markdown]
# ## Paprastos lygtys ★☆☆
# 1\. Nurodyk lygties $x-75=-15$ sprendinį.
# 2\. Nurodyk lygties $x+(-3.5)=-1,5$ sprendinį.
# 3\. Nurodyk lygties $x-(-1.5)=4.5$ sprendinį.
# 4\. Nurodyk lygties $-12\dfrac{1}{3}+x=-1\dfrac{1}{3}$ sprendinį.
# 5\. Nurodyk lygties $-15.5-x=-21.5$ sprendinį.
# 6\. Nurodyk lygties $-52:x=-4$ sprendinį.
# 7\. Nurodyk lygties $-2\dfrac{1}{4}:x=1\dfrac{1}{2}$ sprendinį.
# 8\. Nurodyk lygties $x:\dfrac{3}{4}=-8$ sprendinį.
# 9\. Nurodyk lygties $-4x-8=-12$ sprendinį.
# 10\. Nurodyk lygties $1\dfrac{1}{2}x+2\dfrac{1}{4}=-\dfrac{3}{4}$ sprendinį.
# 11\. Nurodyk lygties $\dfrac{x}{-4}=-7$ sprendinį.
# 12\. Nurodyk lygties $\dfrac{-3x}{5}=\dfrac{9}{15}$ sprendinį.
# 13\. Nurodyk lygties $x:(-2)+17=-15$ sprendinį.
# 14\. Nurodyk lygties $\dfrac{x}{4}-6=-1\dfrac{1}{2}$ sprendinį.

# %% [markdown]
# ## Sudėtingesnės lygtys ★★☆
# 1\. Nurodyk lygties $-4x-6=-3x$ sprendinį.
# 2\. Nurodyk lygties $-40x=-28-33x$ sprendinį.
# 3\. Nurodyk lygties $3x+4=6x-20$ sprendinį.
# 4\. Nurodyk lygties $7-5x=-11-3x$ sprendinį.
# 5\. Nurodyk lygties $4\dfrac{1}{2}x+10=8+2\dfrac{1}{2}x$ sprendinį.
# 6\. Nurodyk lygties $-4.5x-9.7=-0.2x-18.3$ sprendinį.
# 7\. Nurodyk lygties $1\dfrac{1}{2}-3.5x=-8.25-\dfrac{1}{4}x$ sprendinį.
# 8\. Nurodyk lygties $6x+(5-x)=5+(x+2)$ sprendinį.
# 9\. Nurodyk lygties $3x-(1-x)=14+x$ sprendinį.
# 10\. Nurodyk lygties $10x-(3-2x)=17-(x+7)$ sprendinį.
# 11\. Nurodyk lygties $2(x-3)-4(x+1)=10$ sprendinį.
# 12\. Nurodyk lygties $7-3(2x-1)=2x-2(5-x)$ sprendinį.
# 13\. Nurodyk lygties $14+3x-(2x-1)=x-5(3-3x)$ sprendinį.
# 14\. Nurodyk lygties $\dfrac{3}{4}\left (\dfrac{1}{2}x - \dfrac{1}{2} \right)-\dfrac{1}{3}\left ( 1\dfrac{1}{2} -\dfrac{1}{3}x \right )=3\dfrac{1}{2}$ sprendinį.

# %% [markdown]
# ## Lygčių sudarymas ★★★
# 1\. Reiškinių $3x−75$ ir $25−2x$ reikšmės yra lygios. Raskite $x$ reikšmę.
# 2\. Reiškinio $10x−5$ reikšmė yra dvigubai didesnė už reiškinio $4x+5$ reikšmę. Rask $x$ reikšmę.
# 3\. Pirmas skaičius $5$ vienetais didesnis už antrą. Šių skaičių suma lygi $117$. Rask mažesnįjį iš tų skaičių.
# 4\. Stalas ir keturios kėdės kainuoja $480$ eurų. Kiek kainuoja viena kėdė, jeigu stalas yra $60$ eurų brangesnis už vieną kėdę?
# 5\. Stačiakampio ilgis yra $5$ vienetais didesnis už jo plotį. Rask stačiakampio ilgį, jeigu jo perimetras lygus $114$?
# 6\. Iš skaičiaus $79$ atėmus skaičių $3x$ ir $5$ skirtumą, gauta $24$. Rask $x$ reikšmę.
# 7\. Prie sugalvoto skaičiaus pridėjus $11$, tuomet gauta suma padauginta iš $3$. Rezultatą atėmus iš $97$ gauta $49$. Koks skaičius buvo sugalvotas?
# 8\. Pirmoje pintinėje yra dvigubai daugiau grybų negu antroje. Kai iš pirmosios pintinės išėmėme $18$ grybų, o į antrą įdėjome $10$ grybų, tai abiejuose pintinėse grybų tapo po lygiai. Kiek grybų buvo pirmoje pintinėje iš pradžių?
# 9\. Keturių iš eilės einančių skaičių suma lygi $306$. Rask didžiausią iš tų skaičių.
# 10\. Turime trikampį $ABC$. Kraštinė $BC$ yra dvigubai ilgesnė už kraštinę $AB$, o kraštinė $AC$ yra $2$ vienetais ilgesnė už kraštinę $BC$. Trikampio $ABC$ perimetras lygus $87$. Rask kraštinės $BC$ ilgį.
# 11\. Saldainių kilogramas kainuoja $3$ eurais brangiau negu kilogramas sausainių. Už $5$ kilogramus saldainių sumokėta $26$ eurais daugiau negu už $3$ kilogramus sausainių. Kiek eurų kainuoja vienas kilogramas saldainių?
# 12\. Jonas vyresnis už Petrą $15$ metų, o Petras jaunesnis už Joną $6$ kartus. Kiek metų yra Jonui?

# %% [markdown]
# ## Procentai ★☆☆
# 1\. $2,5\%$ paversk dešimtaine trupmena.
# 2\. Kuri iš nurodytų trupmenų atitinka $40\%$?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, \frac{40}{10}&
# \boxed{B}\, \frac{10}{40}&
# \boxed{C}\, \frac{14}{35}&
# \boxed{D}\, \frac{15}{40}
# \end{array}$
# 3\. Paversk procentais trupmeną $\frac{1}{8}$.
# 4\. Klasėje yra $30$ mokinių, iš kurių $30\%$ yra mergaitės. Kiek yra šioje klasėje berniukų?
# 5\. Mokykloje $160$ moksleivių lanko sporto būrelius, o tai sudaro $40\%$ visos mokyklos mokinių skaičiaus. Kiek mokinių mokosi šioje mokykloje?
# 6\. Knygoje yra $300$ puslapių. Kipras jau perskaitė $120$ puslapių. Kiek procentų knygos jam dar liko perskaityti?
# 7\. Dviratininkai turėjo įveikti $200\,\text{km}$ atstumą per tris dienas. Pirmą dieną jie įveikė $24\%$ kelio, o antrą dieną - $62\,\text{km}$. Kiek procentų kelio jiems dar liko įveikti trečią dieną?
# 8\. Suknelė parduotuvėje kainavo $150$ eurų. Per išpardavimą buvo taikoma $30\%$ nuolaida. Kiek kainavo suknelė su nuolaida?
# 9\. Viename miestelyje, kuriame buvo $8000$ gyventojų, vyko rinkimai. Rinkimų dieną atėjo $60\%$ gyventojų, iš kurių $40\%$ balsavo už kandidatą Tomą. Kiek gyventojų balsavo už Tomą?
# 10\. Viename mieste buvo $80000$ gyventojų. Laikui bėgant iš jo išvyko $20\%$ gyventojų, tačiau po kurio laiko gyventojų ir vėl padaugėjo $30\%$. Kiek dabar yra šiame mieste gyventojų?
# 11\. Parduotuvėje viena kėdė kainuoja $80$ eurų, o stalas - $180$ eurų. Vieną dieną kėdė atpigo $20\%$, o stalas pabrango $10\%$. Keliais procentais pasikeitė komplekto iš keturių kėdžių ir vieno stalo kaina?
# 12\. Parduotuvėje batai kainuoja $80$ eurų. Vieną dieną juos pabrangino $10\%$, o kitą dieną juos vėl atpigino $10\%$. Kiek dabar kainuoja batai?

# %% [markdown]
# ## Kampai ir tiesės ★★☆
# 1\. Iš taško $O$ išvesti spinduliai $OA$, $OB$. Tada iš to paties taško išvestos kampų $\angle AOB$, $\angle AOC$, $\angle COB$ pusiaukampinės $OC$, $OD$ ir $OE$. Žinoma, jog $\angle DOE = 30^{\circ}$. Apskaičiuokite $\angle DOB$.
# <img src="../images/7_10_1.png" width="200"/>
# 2\. Kampas AOB – ištiestinis. Remdamiesi brėžiniu, nustatykite, kuris iš žemiau pateiktų teiginių yra neteisingas.
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, ∠AOD \text{ – smailusis} &
# \boxed{B}\, ∠AOC \text{ – bukasis} &
# \boxed{C}\, \angle AOE < \angle DOB &
# \boxed{D}\, ∠DOE \text{ - statusis}
# \end{array}$
# <img src="../images/7_10_2.png" width="200"/>
# 3\. Paveikslėlyje pateiktos dvi susikertančios tiesės. Kuris teiginys apie susidariusius kampus yra teisingas?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, \text{Kampas 1 gretutinis kampams 2 ir 3, o kryžminis kampui 4}&
# \boxed{B}\, \text{Kampas 2 gretutinis kampui 4, o kryžminis kampams 1 ir 3}\\
# \boxed{C}\, \text{Kampas 3 gretutinis kampui 4, o kryžminis kampui 2}&
# \boxed{D}\, \text{Kampas 4 gretutinis kampams 1 ir 3, o kryžminis kampui 2}
# \end{array}$
# <img src="../images/7_10_3.png" width="200"/>
# 4\. Pagal žemiau pateiktus duomenis raskite $\angle 1$, $\angle 2$ ir $\angle 3$.
# <img src="../images/7_10_4.png" width="200"/>
# 5\. $\angle BOC$ – ištiestinis. Iš jo viršūnės išvestas spindulys $OA$. Pagal pateiktus paveikslėlyje duomenis apskaičiuokite $\angle AOB$ dydį.
# <img src="../images/7_10_5.png" width="200"/>
# 6\. Apskaičiuokite $\angle AOC$ ir $\angle BOD$ sumą.
# <img src="../images/7_10_6.png" width="200"/>
# 7\. Vienas kampas sudaro $25\%$ jam gretutinio kampo didumo. Apskaičiuokite mažesniojo iš jų kampo didumą.
# 8\. Tiesės $a$ ir $b$ lygiagrečios, o tiesė $c$ jas kerta. Pagal pateiktus duomenis raskite $\angle 1$, $\angle 2$ ir $\angle 3$.
# <img src="../images/7_10_8.png" width="200"/>
# 9\. Tiesės $a$ ir $b$ lygiagrečios, o tiesė $c$ jas kerta. Pagal pateiktus duomenis apskaičiuokite $\angle 1$.
# <img src="../images/7_10_9.png" width="200"/>
# 10\. Tiesės $a$ ir $b$ lygiagrečios, o tiesė $c$ jas kerta. Pagal pateiktus duomenis apskaičiuokite $\angle 1$.
# <img src="../images/7_10_10.png" width="200"/>
# 11\. Remdamiesi brėžiniu nurodykite, kurios iš tiesių $a$ su $b$ bei $c$ su $d$ yra lygiagrečios. Kurios iš paminėtų tiesių porų nesikerta?
# <img src="../images/7_10_11.png" width="200"/>
# 12\. Kampų kraštines kerta tiesių poros. Išnagrinėkite žemiau pateiktus brėžinius ir pasirinkite, kuri iš tiesių $a$, $b$, $c$ yra lygiagreti tiesei l.
# <img src="../images/7_10_12.png" width="200"/>

# %% [markdown]
# ## Trikampiai ★★☆
# 1\. Žemiau pavaizduoto trikampio perimetras lygus $42$. Apskaičiuokite nežinomą kampo didumą kraštinės ilgį.
# <img src="../images/7_11_1.png" width="200"/>
# 2\. Lygiašonio trikampio kampas prie pagrindo lygus $30^{\circ}$. Kokia šio trikampio rūšis pagal kampus?
# 3\. Kuri iš pavaizduotų atkarpų yra trikampio $ABC$ pusiaukraštinė?
# <img src="../images/7_11_3.png" width="200"/>
# 4\. Trikampio $ACD$ perimetras lygus $19.1$. Raskite trikampių $CDB$ ir $ACB$ perimetrus.
# <img src="../images/7_11_4.png" width="200"/>
# 5\. Atkarpa $CD$ – trikampio $ACB$ pusiaukampinė. Pagal pateiktus brėžinyje duomenis apskaičiuokite $\angle CDB$.
# <img src="../images/7_11_5.png" width="200"/>
# 6\. Iš trikampio $ABC$ kampų $B$ ir $C$ nubrėžtos pusiaukampinės, susikertančios taške $O$. Pagal pateiktus brėžinyje duomenis apskaičiuokite $\angle OAD$.
# <img src="../images/7_11_6.png" width="200"/>
# 7\. Kuri iš pavaizduotų atkarpų nėra trikampio $ABC$ aukštinė?
# <img src="../images/7_11_7.png" width="200"/>
# 8\. Kokių kraštinių ilgių trikampis negali būti nubraižytas?
# $\begin{array}{l{\quad}l{\quad}l{\quad}l}
# \boxed{A}\, 10\,\text{cm},\,1\,\text{cm}\,\text{ir}\,8\,\text{cm} &
# \boxed{B}\, 2\,\text{cm},\,30\,\text{mm}\,\text{ir}\,4\,\text{cm} &
# \boxed{C}\, 5\,\text{cm},\,5\,\text{cm}\,\text{ir}\,9\,\text{cm} &
# \boxed{D}\, 2\,\text{dm},\,150\,\text{mm}\,\text{ir}\,7\,\text{cm}
# \end{array}$
# 9\. Trikampiai ABC ir DEF lygūs. Raskite $\angle B$ ir trikampio $ABC$ perimetrą.
# <img src="../images/7_11_9.png" width="300"/>
# 10\. Remdamiesi brėžiniu užbaikite įrodymą: $\triangle ABD = \triangle BDC$ pagal $\dots$ požymį, nes $\dots$.
# <img src="../images/7_11_10.png" width="100"/>
# 11\. Kuriuo požymiu remiantis galima pagrįsti trikampių $ABC$ ir $DEF$ lygumą?
# <img src="../images/7_11_11.png" width="300"/>
# 12\. Pagal pateiktus brėžinio duomenis apskaičiuokite klaustuku pažymėto kampo dydį, kai žinoma, kad taškai $A$, $O$, $B$ išsidėstę vienoje tiesėje.
# <img src="../images/7_11_12.png" width="400"/>

# %% [markdown]
# ## Trapecijos ir lygiagretainiai ★★☆
#
# 1\. Apskaičiuokite pavaizduoto keturkampio klaustukais pažymėtus kraštinės ilgį ir kampo didumą, kai žinoma, jog šio keturkampio perimetras lygus $37.6$.
# <img src="../images/7_12_1.png" width="200"/>
# 2\. Kuris iš pavaizduotų keturkampių yra trapecija?
# <img src="../images/7_12_2.png" width="200"/>
# 3\. Apskaičiuokite $\angle B$ ir $\angle D$.
# <img src="../images/7_12_3.png" width="200"/>
# 4\. Trapecija $ABCD$ – lygiašonė. Apskaičiuokite jos kampų $A$ ir $C$ didumus bei perimetrą.
# <img src="../images/7_12_4.png" width="200"/>
# 5\. Kuris iš pavaizduotų keturkampių yra lygiagretainis?
# <img src="../images/7_12_5.png" width="200"/>
# 6\. $ABCD$ – lygiagretainis. $BC = 9.5$, $CD=5.8$. Trikampio $ABC$ perimetras lygus $27.7$, o trikampio $ABD$ perimetras lygus $25.3$. Apskaičiuokite trikampio $AOD$ perimetrą.
# <img src="../images/7_12_6.png" width="200"/>
# 7\. $ABCD$ – lygiagretainis. Raskite $\angle D$.
# <img src="../images/7_12_7.png" width="200"/>
# 8\. Kuris iš žemiau pateiktų teiginių yra neteisingas?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, \text{Jei keturkampis yra kvadratas, tai jis yra ir stačiakampis.}&
# \boxed{B}\, \text{Jei keturkampis yra kvadratas, tai jis yra ir rombas.}\\
# \boxed{C}\, \text{Jei keturkampis yra rombas, tai jis yra ir lygiagretainis.}&
# \boxed{D}\, \text{Jei keturkampis yra lygiagretainis, tai jis yra ir stačiakampis.}
# \end{array}$
# 9\. $ABCD$ – stačiakampis. Apskaičiuokite klaustuku pažymėto kampo dydį.
# <img src="../images/7_12_9.png" width="200"/>
# 10\. $ABCD$ – rombas. Pagal paveikslėlyje duotus duomenis apskaičiuokite klaustuku pažymėto kampo dydį.
# <img src="../images/7_12_10.png" width="200"/>
# 11\. Rombo įstrižainių ilgiai lygūs $6$ ir $8$, o kraštinės ilgis lygus $5$. Apskaičiuokite šio rombo perimetrą ir plotą.
# 12\. $ABCD$ – kvadratas. Iš jo įstrižainės $AC$ taško $O$ išvestas spindulys $OP$, lygiagretus kvadrato kraštinėms $AB$ ir $CD$. Raskite kampo $POC$ dydį.
# <img src="../images/7_12_12.png" width="120"/>
# 13\. Taisyklingieji penkiakampis ir šešiakampis turi vieną bendrą kraštinę. Apskaičiuokite šešiakampio perimetrą, kai žinoma, jog penkiakampio perimetras lygus $12$
# <img src="../images/7_12_13.png" width="120"/>
# 14\. $ABCD$ – lygiašonė trapecija. Žinoma, kad $P_{\triangle ABC} = 25.5$. Apskaičiuokite trikampio $COD$ perimetrą.
# <img src="../images/7_12_14.png" width="200"/>

# %% [markdown]
# ## Erdviniai kūnai ★☆☆
# 1\. Kiek viršūnių turi taisyklingoji šešiakampė piramidė?
# 2\. Kiek briaunų turi taisyklingoji penkiakampė piramidė?
# 3\. Kiek sienų turi taisyklingoji aštuonkampė piramidė?
# 4\. Kiek viršūnių turi taisyklingoji trikampė prizmė?
# 5\. Kiek sienų turi taisyklingoji keturkampė prizmė?
# 6\. Kiek briaunų turi taisyklingoji septynkampė prizmė?
# 7\. Rask pavaizduotos taisyklingosios keturkampės prizmės tūrį ir viso paviršiaus plotą.
# $ABCD$ – lygiašonė trapecija. Žinoma, kad $P_{\triangle ABC} = 25.5$. Apskaičiuokite trikampio $COD$ perimetrą.
# <img src="../images/7_13_7.png" width="200"/>
# 8\. Rask pavaizduotos taisyklingosios trikampės prizmės tūrį ir viso paviršiaus plotą.
# <img src="../images/7_13_9.png" width="200"/>
# $ABCD$ – lygiašonė trapecija. Žinoma, kad $P_{\triangle ABC} = 25.5$. Apskaičiuokite trikampio $COD$ perimetrą.
# 9\. Kubo viso paviršiaus plotas lygus $294$ kvadratiniams vienetams. Kam lygi šio kubo visų briaunų ilgių suma?
# 10\. Stačiakampio gretasienio formos metalinio konteinerio matmenys yra tokie: $6\,\text{m}\times25\,\text{dm}\times 25\,\text{dm}$. Kiek reikėtų dažų skardinių jam visam nudažyti, jeigu vienos skardinės pakanka $2.5\,\text{m}^2$ plotui nudažyti?
# 11\. Kubo viso paviršiaus plotas lygus $294$ kvadratiniams vienetams. Kam lygi šio kubo visų briaunų ilgių suma?
# 12\.  Stačiakampio gretasienio formos metalinio konteinerio matmenys yra tokie: $6\,\text{m}\times 25\,\text{dm}\times 25\,\text{dm}$. Kiek reikėtų dažų skardinių jam visam nudažyti, jeigu vienos skardinės pakanka $2{,}5\,\text{m}^2$ plotui nudažyti?

# %% [markdown]
# ## Septintos klasės kurso kartojimas ★★☆
# 1\. Apskaičiuokite $1-4+(-5)+20-(-7)$
# 2\. Apskaičiuokite $1\dfrac{2}{5}-2\dfrac{1}{4}-\dfrac{2}{5}+\dfrac{5}{4}$
# 3\. Apskaičiuokite $-|-5| - |-4| + |-6|$
# 4\. Batai parduotuvėje kainuoja $80$ eurų. Pradžioje kaina buvo pakelta $20\%$, bet po kiek laiko kaina buvo pakelta dar $10\%$. Kiek dabar kainuoja batai?
# 5\. Mato matematikos pažymiai yra: $6$, $10$, $8$, $6$, $6$, $8$, $10$. Matas parašė dar vieną matematikos darbą, iš kurio gavo dar vieną aštuntuką. Koks Mato matematikos pažymių vidurkis? Atsakymą užrašyk dešimtaine trupmena.
# 6\. Suprastinkite reiškinį $1\dfrac{3}{5}x+3{,}2-0{,}6x-\dfrac{6}{5}$
# 7\. Išspręskite lygtį $3x−5=6x+7$
# 8\. Apskaičiuokite $-2^2 - (-3)^3 - \sqrt{81}$
# 9\. Gretutinių kampų santykis $4:5$. Keliais laipsniais skiriasi šie kampai?
# 10\. Smailiajame lygiašoniame trikampyje $ABC$, $AB=BC$, aukštinė $CE=4\,\text{cm}$. Koks aukštinės $AD$ ilgis?
# 11\. Lygiašonės trapecijos perimetras yra $24\,\text{cm}$. Šoninė trapecijos kraštinė lygi pagrindų sumos pusei. Koks šoninės kraštinės ilgis?
# 12\. Kiek kartų padidės kvadrato plotas, jeigu jo kraštinę padidinsime $5$ kartus?
# 13\. Raskite rombo plotą, jeigu jo įstrižainės yra atitinkamai lygios $6\,\text{cm}$ ir $8\,\text{cm}$?
# 14\. Stačiakampio ilgis yra lygus $15\,\text{cm}$, o plotis yra $15\%$ trumpesnis už ilgį. Kam lygus šio stačiakampio plotas?

# %% [markdown]
# #### In total
# 10 + 14 + 14 + 14 + 14 + 14 + 14 + 12 + 12 + 12 + 12 + 14 + 12 + 14 = 182 (14 topics)

# %%
s = [1, 2, 3, 4, 5, 6]
from itertools import product

for n in list(product(s, repeat=2)):
    print(f'{n[0]}+{n[1]}={sum(n)}')
# Out:
# 1+1=2
# 1+2=3
# 1+3=4
# 1+4=5
# 1+5=6
# 1+6=7
# 2+1=3
# 2+2=4
# 2+3=5
# 2+4=6
# 2+5=7
# 2+6=8
# 3+1=4
# 3+2=5
# 3+3=6
# 3+4=7
# 3+5=8
# 3+6=9
# 4+1=5
# 4+2=6
# 4+3=7
# 4+4=8
# 4+5=9
# 4+6=10
# 5+1=6
# 5+2=7
# 5+3=8
# 5+4=9
# 5+5=10
# 5+6=11
# 6+1=7
# 6+2=8
# 6+3=9
# 6+4=10
# 6+5=11
# 6+6=12
