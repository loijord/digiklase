# %% [markdown]
# Esant poreikiui pateikiu kai kurių skyrių uždavinių sprendimus
#
# * [11 klasė, aritmetinė progresija](11kl_aritmetinė_progresija.ipynb)
# * [11 klasė, geometrinė progresija](11kl_geometrinė_progresija.ipynb)
# * [11 klasė, funkcijos samprata](11kl_funkcijos_samprata.ipynb)
