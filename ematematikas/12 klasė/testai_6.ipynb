# %% [markdown]
# ## Duomenų statistika ★☆☆
# 1\. Kurios iš žemiau pateiktų imčių moda ir mediana sutampa?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, 2, 2, 3, 3, 4, 4 &
# \boxed{B}\, 2, 2, 2, 3, 3, 4 \\
# \boxed{C}\, 2, 3, 3, 3, 4, 4 &
# \boxed{D}\, 2, 3, 3, 4, 4, 4
# \end{array}$
# 2\. Vienos klasės matematikos kontrolinio darbo pažymiai yra tokie:
# $5$, $7$, $9$, $4$, $5$, $8$, $9$, $10$, $4$, $5$, $3$, $8$, $8$, $5$, $10$, $2$.
# * Koks visos klasės pažymių vidurkis?
# * Kokia visos klasės pažymių moda?
# * Kokia visos klasės pažymių mediana?
#
# 3\. Žemiau esančioje lentelėje pateikti vienos klasės moksleivių išmatuotų ūgių duomenys.
# $\begin{array}{|c|c|} \hline
# \text{Ūgis (cm)} & 166 & 167 & 172 & 175 & 180 \\ \hline
# \text{Dažnis} & 3 & 4 & 7 & 4 & 2 \\ \hline
# \end{array}$
# * Kiek moksleivių mokosi šioje klasėje?
# * Kokia šios klasės ūgių duomenų moda?
# * Kokia šios klasės ūgių duomenų mediana?
# * Koks šios klasės moksleivių ūgio vidurkis?
#
# 4\. Žemiau esančioje lentelėje pateikti $1000$ apklaustų žmonių duomenys apie jų praleidžiamą laiką prie televizoriaus ekrano.
# $\begin{array}{|c|c|} \hline
# \text{Valandos} & 0 & 1 & 2 & 3 & 4 \\ \hline
# \text{Dažnis} & 122 & 131 & 148 & 255 & 344 \\ \hline
# \end{array}$
# * Kokia apklaustų žmonių duomenų mediana?
# * Koks visų apklaustų žmonių praleisto laiko prie TV vidurkis?
#
# 5\. Žemiau esančioje lentelėje pateikti 300
#  apklaustų žmonių duomenys apie jų žiūrimų serialų skaičių.
# $\begin{array}{|c|c|} \hline
# \text{Skaičius} & 0 & 1 & 2 & 3 & 4 & 5\\ \hline
# \text{Dažnis} & 38 & 56 & 56 & 58 & 34 & 58 \\ \hline
# \end{array}$
#
# * Kokia apklaustų žmonių duomenų mediana?
# * Kokia apklaustų žmonių duomenų moda?
#
# 6\. Vienos klasės mergaičių kontrolinio darbo įvertinimų vidurkis yra $9$, o berniukų - $8$. Visos klasės pažymių vidurkis yra lygus $8{,}64$. Kiek klasėje yra berniukų, jeigu mergaičių yra $16$?
# 7\. Taškinėje diagramoje pavaizduota, koks mokinių skaičius kiek vidutiniškai minučių pavėluoja į pamokas.
# <img src="../images/12_14_7.png" width="300"/>
# * Nustatykite šios imties modą.
# * Nustatykite šios imties medianą.
#
# 8\. Lentelėje pateikti vienos klasės moksleivių per vasarą perskaitytų knygų skaičiaus apklausos duomenys.
# $\begin{array}{|c|c|}
# \hline \text{Knygų sk.} & 0 & 1 & 2 & 3 & 4 \\
# \hline \text{Dažnis} & 8 & ? & 8 & 3 & 3 \\
# \hline \end{array}$
# Kiek daugiausia moksleivių galėjo perskaityti vieną knygą, kai šios apklausos mediana lygi $2$?

# %% [markdown]
# ## Atsitiktiniai dydžiai ★★☆
# 1\. Atsitiktinio dydžio $X$ skirstinys pateiktas žemiau esančia lentele. Apskaičiuokite šio atsitiktinio dydžio matematinę viltį.
# $\begin{array}{|c|c|}
# \hline X & 1 & 2 & 3 \\
# \hline P(X) & p & 0{,}2 & 0{,}5 \\
# \hline \end{array}$
# 2\. Pasinaudoję atsitiktinio dydžio $X$ reikšmių tikimybių lentele, apskaičiuokite šio atsitiktinio dydžio matematinę viltį.
# $\begin{array}{|c|c|}
# \hline X & 1 & 2 & 3 & 4 \\
# \hline P(X) & p & 0{,}2 & p & 0{,}3 \\
# \hline \end{array}$
# 3\. Pateikta atsitiktinio dydžio $X$ skirstinio lentelė. Yra žinoma, kad šio atsitiktinio dydžio matematinė viltis $EX=2{,}9$. Apskaičiuokite $a$ reikšmę.
# $\begin{array}{|c|c|}
# \hline X & 0 & 2 & 4 & 6 \\
# \hline P(X) & 0{,}3 & a & 0{,}25 & b \\
# \hline \end{array}$
# 4\. Pateikta atsitiktinio dydžio $X$ skirstinio lentelė. Yra žinoma, kad šio atsitiktinio dydžio matematinė viltis $EX=3{,}2$. Apskaičiuokite $m$ reikšmę.
# $\begin{array}{|c|c|}
# \hline X & 2 & 5 \\
# \hline P(X) & m & n \\
# \hline \end{array}$
# 5\. Pateikta atsitiktinio dydžio $X$ skirstinio lentelė. Yra žinoma, kad šio atsitiktinio dydžio matematinė viltis $EX=4{,}4$. Apskaičiuokite $a$ reikšmę.
# $\begin{array}{|c|c|}
# \hline X & 1 & 3 & 4 & 7 \\
# \hline P(X) & a & b & a & b \\
# \hline \end{array}$
# 6\. Pateiktas atsitiktinio dydžio skirstinys. Kam lygi tikimybė $P(X \le 5)$?
# $\begin{array}{|c|c|}
# \hline X & 1 & 3 & 4 & 7 \\
# \hline P(X) & 0{,}15 & 0{,}35 & 0{,}25 & 0{,}25 \\
# \hline \end{array}$
# 7\. Atsitiktinio dydžio $X$ skirstinys pateiktas lentele. Apskaičiuokite šio atsitiktinio dydžio dispersiją. Atsakymą nurodykite dešimtaine trupmena.
# $\begin{array}{|c|c|}
# \hline X & 0 & 2 & 4 \\
# \hline P(X) & 0{,}2 & 0{,}3 & 0{,}5 \\
# \hline \end{array}$
# 8\. Atsitiktinio dydžio $X$ skirstinys pateiktas lentele. Nurodykite šio atsitiktinio dydžio standartinį nuokrypį. Atsakymą nurodykite šimtųjų tikslumu.
# $\begin{array}{|c|c|}
# \hline X & 1 & 2 & 3 \\
# \hline P(X) & a & a & a \\
# \hline \end{array}$
# 9\. Per krepšinio varžybas prieš žaidėją buvo prasižengta, todėl jis gavo galimybę mesti dvi baudas. Žaidėjo vieno metimo pataikymo tikimybė yra $0{,}6$. Atsitiktinis dydis $X$ - žaidėjo pataikytų baudų skaičius. Pabaikite pildyti atsitiktinio dydžio $X$ skirstinio lentelę ir apskaičiuokite atsitiktinio dydžio $X$ matematinę viltį.
# $\begin{array}{|c|c|}
# \hline X & 0 & 1 & 2 \\
# \hline P(X) & & & \\
# \hline \end{array}$
# 10\. Dėžutėje yra keturios kortelės, ant kurių užrašyti skaičiai nuo $1$ iki $4$. Atsitiktinai paimamos dvi kortelės. Ant paimtųjų kortelių užrašytų skaičių suma yra atsitiktinis dydis. Pažymėkime jį $X$. Pabaikite pildyti atsitiktinio dydžio $X$ skirstinio lentelę ir apskaičiuokite atsitiktinio dydžio $X$ matematinę viltį.
# $\begin{array}{|c|c|}
# \hline X & 3 & 4 & 5 & 6 & 7 \\
# \hline P(X) & \dfrac{1}{6} & & \\
# \hline \end{array}$
