# %% [markdown]
# # 11 klasė
# * [Skaičiavimai](testai_1.ipynb) (5)
# * [Trigonometrija](testai_2.ipynb) (2)
# * [Aritmetinė ir geometrinė progresija](testai_3.ipynb) (2)
# * [Vektoriai](testai_4.ipynb) (2)
# * [Lygtys ir lygčių sistemos](testai_5.ipynb) (6)
# * [Nelygybės](testai_6.ipynb) (4)
# * [Funkcijos](testai_7.ipynb) (3)
#
# # Uždavinių sprendimai
#
# 8\. Su tam tikra sveikųjų skaičių pora $(x;\;y)$ skaičių sekos $x$; $xy$; $11x$ ir $y^2$; $x^2$; $x+y+3$ yra aritmetinės proresijos. Nustatykite reiškinio $y^2 - x^2$ reikšmę.
#
# **Sprendimas.**
#
# $\begin{cases} xy - x = 11x - xy \\ x^2 - y^2 = x + y + 3 - x^2 \end{cases}$
#
# Jei $x \neq 0$, tai pirmą lygtį daliname iš $x$:  $\boxed{y - 1 = 11 - y} \Leftrightarrow \boxed{2y = 12} \Leftrightarrow \boxed{y=6}$.
#
# Tada iš antros lygties $\boxed{x^2 - 36 = x + 9 - x^2} \Leftrightarrow \boxed{2x^2 - x - 45 = 0} \Leftrightarrow \boxed{(x - 5)(2x + 9) = 0}$.
#
# Sveikoji $x$ reikšmė, tenkinanti lygtį, yra $x = 5$, tada $y^2 - x^2 = 36 - 25 = 11$.
#
# Jei $x = 0$, tai iš antros lygties $\boxed{- y^2 = y + 3} \Leftrightarrow \boxed{y^2 + y + 3 = 0}$. Ši lygtis neturi sprendinių, nes $D$ neigiamas.
#
# 9\. Aritmetinės progresijos, turinčios $32$ narius, paskutinysis narys lygus $-52{,}5$, o jos skirtumas lygus $-2{,}5$. Apskaičiuokite visų šios progresijos narių sumą.
#
# **Sprendimas.**
# $x_1 + 31\cdot (-2{,}5) = -52{,}5 \Leftrightarrow x_1 - 77{,}5 = -52{,}5$. Iš čia $x_1 = 25$. Tuomet narių suma $32 \cdot \dfrac{25 + (-52{,}5)}{2} = -440$.
#
# 10\. Raskite sumos $a_{61} + a_{62} + a_{63} + \dots + a_{118} + a_{119} + a_{120}$ reikšmę, jei $a_n = -2 + \dfrac{1}{30}n$.
# **Sprendimas.**
# Kai $n$ padidinamas $1$, sekos nario reikšmė padidėja $\dfrac{1}{30}$, vadinasi seka yra aritmetinė progresija su vardikliu $d = \dfrac{1}{30}$.
# $a_{120} = 2$, $a_{61}  = -2 + \dfrac{1}{30}\cdot 61 = \dfrac{1}{30}$. Iš viso sudedame $60$ narių. Atsakymas $60 \cdot \dfrac{\frac{1}{30} + 2}{2} = 30 \cdot \left(\frac{1}{30} + 2 \right) = 61$
#
# 11\. Sudedami natūralieji skaičiai, kuriuos dalijant iš $5$ gaunama liekana $2$. Kiek tokių skaičių buvo sudėta, jei gauta suma lygi $6996$ ?
# **Sprendimas.**
# $a_1 = 2$; $a_n = 2 + 5(n-1)$; $S = n \cdot \dfrac{a_1 + a_n}{2} = n \cdot \dfrac{2 + 2 + 5(n-1)}{2} = n \cdot \dfrac{5n - 1}{2} = \dfrac{5n^2 - n}{2} = 6996$
#
# $5n^2 - n - 13992 = 0$; $D = 1 - 4\cdot 5 \cdot (-13992) = 279841 = 529^2$; $n_1 = \dfrac{1 + 529}{10} = 53$; $n_1 = \dfrac{1 - 529}{10} = -52{,}8$. Atsakymas: 53 nariai.
#
# 12\. $a_n$ - aritmetinė progresija. $S_{25} = 975$ ir $S_{40} = 2460$. Raskite $a_{33}$.
#
# **Sprendimas.**
# $S_{25} = \boxed{25 \cdot \dfrac{a_1 + (a_1 + 24d)}{2} = 975} \Leftrightarrow \boxed{2a_1 + 24d = 78}$
# $S_{40} = \boxed{40 \cdot \dfrac{a_1 + (a_1 + 39d)}{2} = 2460} \Leftrightarrow \boxed{2a_1 + 39d = 123}$
#
# Atėmę pirmą lygtį iš antros, gauname $\boxed{15d = 45} \Leftrightarrow \boxed{d = 3}$. Įstatę $d=3$ į pirmą lygtį, turėsime $\boxed{2a_1 + 72 = 78} \Leftrightarrow \boxed{a_1 = 3}$. Tada $a_{33} = a_1 + 32d = 3 + 32\cdot 3 = 99$.
#
# 13\. Aritmetinės progresijos pirmųjų $n$ narių sumos formulė yra: $S_n = -n(2n+1)$. Raskite šios progresijos dešimtąjį narį.
#
# **Sprendimas.**
# $a_{10} = S_{11} - S_{10} = -11\cdot(2\cdot 11+1) - (-10\cdot(2\cdot 10+1)) = -253 -(-210)=-43$
#
# 14\. Žemiau pateiktos keturių aritmetinių progresijų pirmųjų $n$
#  narių sumų formulės. Kuri iš jų yra didėjančiosios aritmetinės progresijos?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, S_{n}=\dfrac{(9-n)n}{2}&
# \boxed{B}\, S_{n}=-2n^2-n\\
# \boxed{C}\, S_{n}=\dfrac{n(3n-5)}{2}&
# \boxed{D}\, S_{n}=3n
# \end{array}$
# **Sprendimas (žr. taip pat kitos pastabos)**
# Galima išvesti, kad bet kurios aritmetinės progresijos sumos formulė $S_n = An^2 + Bn$. Tuomet $\begin{cases} \boxed{d = 2A} \\ a_1 = A + B \end{cases}$. Aritmetinė progresija didėja, kai $\boxed{d>0} \Leftrightarrow \boxed{A > 0}$. Renkamės variantą $C$, nes tik šiuo atveju $S_n$ yra formos $An^2 + Bn$ ir koefcientas $A$ yra teigiamas.
#
# 15\. Gamykloje gaminamos tam tikros rūšies detalės. Pirmąją dieną buvo pagamintos $4$ detalės, o kiekvieną kitą dieną buvo pagaminta $3$ detalėmis daugiau nei praėjusią dieną. Žinoma, kad per $10$ dienų buvo pagaminta $7\%$ visų planuojamų pagaminti detalių. Po kelių dienų buvo įvykdytas planas?
#
# Pirmųjų $10$ dienų suma: $4 + 7 + 10 + \dots + 31 = 10\cdot \dfrac{4 + 31}{2} = 175$.
#
# $\boxed{\begin{array}{rcl} 175 & - & 7\% \\ x & - & 100\% \end{array}} \Leftrightarrow \boxed{7x = 175\cdot 100} \Leftrightarrow \boxed{x=2500}$
#
# Tegu $n$ - dienų skaičius. Tada:
# $\boxed{n \cdot \dfrac{4 + 4 + (n-1)\cdot 3}{2} = 2500} \Leftrightarrow \boxed{n \cdot (5 + 3n) = 5000} \Leftrightarrow \boxed{3n^2 + 5n - 5000 = 0} \Leftrightarrow n_1 = \dfrac{-5 + \sqrt{5^2 - 4\cdot 3 \cdot (-5000)}}{2\cdot 3} =  \dfrac{-5 + 245}{2\cdot 3} = 40$.
#
# Kitas sprendinys neigiamas.
#
# ## Kitos pastabos
#
# Kai kuriuose uždaviniuose buvo pateiktos pirmųjų $n$ narių sumos formulės $S_n = f(n)$, kur $f(n)$ yra kvadratinė funkcija.
# **Uždavinys.** Pagal pateiktą pirmųjų $n$ narių sumos formulę $S_n = f(n)$ nustatyti $n$ - tojo nario $a_n$ formulę ir skirtumo $d$ formulę (**šios formulės žinoti nebūtina**).
# **Sprendimas.** Randame $S_n$ išraišką ir pertvarkome gautą reiškinį taip, kad šioje išraiškoje matytųsi kvadratinės funkcijos koeficientai.
# * $S_n = n \left(\dfrac{a_{1} + a_n}{2}\right) = n \left(\dfrac{a_{1} + \left(a_1 + (n-1)d\right))}{2}\right) =
# n \left(\dfrac{2a_{1} + nd - d)}{2}\right) = n\left(n\cdot\dfrac{d}{2} + a_1 - \dfrac{d}{2}\right) = \dfrac{d}{2}\cdot n^2 + \left(a_1 - \dfrac{d}{2}\right)\cdot n = An^2 + Bn$.
#
# Jei $A$ ir $B$ yra žinomi skaičiai, tai turime lygčių sistemą:
# $\begin{cases} \dfrac{d}{2} = A \\ a_1 - \dfrac{d}{2} = B \end{cases} \Leftrightarrow \begin{cases} \boxed{d = 2A} \\ a_1 = A + B \end{cases}$
# Iš čia $a_n = a_1 + d\cdot(n - 1) = A + B + 2A\cdot (n-1) = A + B + 2An - 2A = \boxed{2An + B - A}$
#
# **Pavyzdys.** Rasime $a_n$, kai $S_n = -n(2n+1)$ (žr. 13 uždavinį).
# **Sprendimas.** $S_n = -n(2n+1) = -2n^2 - n$. Tada $A = -2$, $B=-1$. Remdamiesi gautomis išvadomis, turime:
# $\begin{cases} a_n = 2An + B - A = -4n + 1 \\ d = -4 \end{cases}$
# **Patikrinimas.** $S_n = n \cdot \left(\dfrac{a_{1} + a_n}{2}\right) = n \cdot \dfrac{-3 -4n+1}{2} = n \cdot \dfrac{-2 -4n}{2} = n(-2n - 1) = -n(2n+1)$

# %% [markdown]
# ## Geometrinė progresija ★★☆
# 1\. Kuri iš duotųjų sekų yra geometrinė progresija?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, 5,\,10,\,15&
# \boxed{B}\, -9,\,3,\,-1 \\
# \boxed{C}\, 3,\,9,\,18 &
# \boxed{D}\, 1,\,-7,\,-49
# \end{array}$
#
# **Sprendimas**
# $\boxed{B}$ variantui turime geometrinės progresijos vardiklį $q = \dfrac{3}{-9} = \dfrac{-1}{3}$.
#
# 2\. Duoti pirmieji du geometrinės progresijos nariai: $18$; $6$. Kuri iš šių formulių aprašo duotąją seką?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, b_n=\dfrac{54}{3^n}&
# \boxed{B}\, b_n=30-12n \\
# \boxed{C}\, b_n=18\cdot\left(\dfrac{1}{3}\right)^n &
# \boxed{D}\, b_n=18-3(n-1)
# \end{array}$
# Turime $q = \dfrac{6}{18} = \dfrac{1}{3}$; $b_n = b_1 \cdot q^{n-1} = 18 \cdot \left(\dfrac{1}{3}\right)^{n-1} = 18 \cdot \left(\dfrac{1}{3}\right)^{n} \cdot \left(\dfrac{1}{3}\right)^{-1} = 18 \cdot \left(\dfrac{1}{3}\right)^{n} \cdot 3 = 54 \cdot \left(\dfrac{1}{3}\right)^{n}$.
# Matome, kad šis reiškinys tapatus su variantu $\boxed{A}$
#
# 3\. Seka $b_n$ - geometrinė progresija. Žinoma, kad: $b_5 = 2$ ir $b_9 = \dfrac{2}{81}$. Raskite $b_7$.
#
# **Sprendimas 1.**
# $b_7 = b_5 \cdot q^2 = \sqrt{b_5 \cdot (b_5 \cdot q^4)} = \sqrt{b_5 \cdot b_9} = \sqrt{2 \cdot \dfrac{2}{81}} = \sqrt{\dfrac{4}{81}} = \dfrac{2}{9}$
# **Sprendimas 2.**
# $q^4 = \dfrac{b_9}{b_5} = \dfrac{\frac{2}{81}}{2} = \dfrac{1}{81} \Rightarrow q = \pm\dfrac{1}{3}$.
# $b_7 = b_5 \cdot q^2 = b_5 \cdot \left(\pm\dfrac{1}{3}\right)^2 = b_5 \cdot \dfrac{1}{9} = \dfrac{2}{9}$.
#
# 4\. Su tam tikra $x$ reikšme skaičių seka $2^x;\;108;\;3^{x+2}$ yra geometrinė progresija. Kam lygus jos vardiklis?
# **Sprendimas.**
# Seka yra geometrinė progresija, kai $\boxed{\dfrac{108}{2^x} = \dfrac{3^{x+2}}{108}} \Leftrightarrow \boxed{\dfrac{108}{2^x} = \dfrac{3^x \cdot 3^2}{108}} \Leftrightarrow \boxed{\dfrac{108}{2^x} = \dfrac{3^x \cdot 9}{108}} \Leftrightarrow \boxed{\dfrac{108}{2^x} = \dfrac{3^x}{12}} \Leftrightarrow \boxed{108 \cdot 12 = 2^x \cdot 3^x} \Leftrightarrow \boxed{1296 = 6^x} \Leftrightarrow \boxed{6^4 = 6^x} \Leftrightarrow \boxed{x=4}$.
# Geometrinės progresijos vardiklis: $q = \dfrac{108}{2^x} = \dfrac{108}{2^4} = \dfrac{4\cdot 27}{4 \cdot 4} = \dfrac{27}{4} = {\large {6}}\dfrac{3}{4}$.
# 5\. Duotos keturių geometrinių progresijų bendrojo nario formulės. Kuri iš jų yra mažėjančiosios geometrinės progresijos?
# $\begin{array}{l{\quad}l}
# \boxed{A}\, b_n=\dfrac{1}{5}\cdot 4^n &
# \boxed{B}\, b_n=-3\cdot \left(\dfrac{1}{2}\right)^n \\
# \boxed{C}\, b_n=5^{3-n} &
# \boxed{D}\, b_n=4\cdot \left(-\dfrac{2}{3}\right)^n
# \end{array}$
# **Sprendimas.** Nagrinėjame kiekvieną iš pateiktų variantų.
# * $\boxed{A}$ variante $b_1 = \dfrac{4}{5}$ ir $q = 4$. Progresijos nariai artėja link $+\infty$.
# * $\boxed{B}$ variante $b_1 = -\dfrac{3}{2}$ ir $q = \dfrac{1}{2}$. Progresija nykstamoji, jos nariai artėja link $0$ iš kairės (visi nariai mažesni už $0$).
# * $\boxed{C}$ variante $b_1 = 25$, $b_2 = 5$ ir $q = \dfrac{1}{5}$. Progresija nykstamoji, jos nariai artėja link $0$ iš dešinės (visi nariai didesni už $0$).
# * $\boxed{D}$ variante $b_1 = -\dfrac{8}{3}$, $q = -\dfrac{2}{3}$. Progresija nykstamoji, jos nariai alteruoja (artėja link $0$ iš abiejų pusių).
#
# Renkamės variantą $\boxed{C}$.
# 6\. Geometrinės pirmasis narys lygus $3$. Jos ketvirtojo ir septintojo narių suma yra $4$ kartus didesnė už jos trečiojo ir šeštojo narių sumą. Kam lygus penktasis šios progresijos narys?
# **Sprendimas.**
# $\boxed{b_4 + b_7 = 4(b_3 + b_6)} \Leftrightarrow \boxed{q^3b_1 + q^6b_1 = 4(q^2b_1 + q^5b_1)} \Leftrightarrow \boxed{b_1\cdot q^3 \cdot (1 + q^3) = 4b_1\cdot q^2 \cdot (1 + q^3)} \Leftrightarrow \boxed{q = 4}$.
# $b_5 = b_1\cdot q^4 = 3 \cdot 4^4 = 3 \cdot 256 = \boxed{768}$.
# 7\. $b_n$ - geometrinė progresija. Jos pirmasis narys yra $4$, o vardiklis lygus $\dfrac{24}{25}$. Kiek ši geometrinė progresija turi narių, didesnių už $1$?
# **Sprendimas.**
# $\boxed{b_n > 1} \Leftrightarrow \boxed{b_1\cdot q^{n-1} > 1} \Leftrightarrow \boxed{4\cdot \left(\dfrac{24}{25}\right)^{n-1} > 1} \Leftrightarrow \boxed{\left(\dfrac{24}{25}\right)^{n-1} > \dfrac{1}{4}} \Leftrightarrow \boxed{n - 1 < \log_{\frac{24}{25}}\dfrac{1}{4}} \Leftrightarrow \boxed{n < 1 + \log_{\frac{24}{25}}\dfrac{1}{4} \approx 1 + 33{,}96 = 34{,}96}$
# Atsakymas: 34 narius ($b_{34} = 4 \cdot \left(\dfrac{24}{25}\right)^{33} \approx 1{,}04$ ir $b_{35} = 4 \cdot \left(\dfrac{24}{25}\right)^{34} \approx 0{,}998$)
#
# 8\. $b_n = \dfrac{3}{20} \cdot 4^{n-1}$. Kam lygi suma $b_1+b_2+\dots+b_{100}$?
# **Sprendimas.**
# $b_n = b_1 \cdot q^{n-1} = \dfrac{3}{20} \cdot 4^{n-1}$
# Pateikta lygybė yra teisinga su tam tikra $b_1$ reikšme ir kiekvienam $n \in \mathbb{N}$. Iš čia $b_1 = \dfrac{3}{20}$ ir $q = 4$ (Ar galite šias gautas lygybes pagrįsti?).
# Skaičiuojant ieškomą sumą siūlau pakartoti formulės išvedimą:
# $b_1 + b_2 + \dots + b_n = b_1 + b_1q + b_1q^2 + \dots + b_1q^{n-1} = b_1(1 + q + q^2 + \dots + q^{n-1}) = b_1\cdot \dfrac{q^n - 1}{q - 1} = \dfrac{3}{20} \cdot \dfrac{4^n - 1}{3} = \dfrac{1}{20} \cdot (4^n - 1)$.
# $b_1 + b_2 + \dots + b_{100} = \dfrac{4^{100} - 1}{20}$.
#
# 9\. Duota seka: $b_n = 3\cdot 2^n$. Raskite $n$, su kuriuo $S_n = 196602$.
# **Sprendimas.**
# $\boxed{b_1q^{n-1} = 3\cdot 2^n} \Leftrightarrow \boxed{b_1q^{n-1} = 3\cdot 2 \cdot 2^{n-1}} \Leftrightarrow \boxed{b_1q^{n-1} = 6 \cdot 2^{n-1}} \Leftrightarrow \boxed{b_1 = 6\text{ ir }q = 2}$
# Šios geometrinės progresijos sumos formulė $S_n = b_1 \cdot \dfrac{q^n - 1}{q - 1} = 6 \cdot (2^n - 1)$
# $\boxed{6 \cdot (2^n - 1) = 196602} \Leftrightarrow \boxed{2^n - 1 = 32767} \Leftrightarrow \boxed{2^n = 32768} \Leftrightarrow \boxed{n = \log_{2} 32768} \Leftrightarrow \boxed{n = 15}$.
#
# 10\. Kam lygi suma: $216 + 36 + 6 + 1 + \dots$?
# **Sprendimas.**
# $S = b_1 \cdot \dfrac{1}{1-q} = 216 \cdot \dfrac{1}{1-\frac{1}{6}} = 216 \cdot \dfrac{1}{\frac{5}{6}} = 216 \cdot \dfrac{6}{5} = 259{,}2$.
#
# 11\. Raskite nykstamosios geometrinės progresijos teigiamą vardiklį, kai žinoma, kad jos pirmųjų dviejų narių suma lygi $10{,}5$, o visų kitų narių (t.y. pradedant trečiuoju) suma lygi $0{,}3$.
#
# **Sprendimas.**
# $\begin{cases} b_1 \cdot \dfrac{1}{1-q} = 10{,}8 \\ b_1 + b_1q = 10{,}5 \end{cases}
# \Leftrightarrow \begin{cases} b_1 = 10{,}8 (1 - q) \\ b_1 (1 + q) = 10{,}5\end{cases}$
#
# Iš antros lygties $\boxed{10{,}8 (1 - q)(1 + q) = 10{,}5} \Leftrightarrow \boxed{108(1 - q^2) = 105} \Leftrightarrow \boxed{1 - q^2 = \dfrac{105}{108}} \Leftrightarrow \boxed{q^2 = \dfrac{3}{108} = \dfrac{1}{36}} \Leftrightarrow \boxed{q = \dfrac{1}{6}\,\text{jei }q>0}$
#
# 12\. Geometrinės progresijos pirmųjų $n$ narių sumos formulė yra: $S_n = \dfrac{1-3^n}{9}$. Kam lygus dešimtasis šios progresijos narys?
#
# **Sprendimas 1.** (nesurandant sekos nario formulės)
# $b_{10} = S_{10} - S_{9} = \dfrac{1-3^{10}}{9} - \dfrac{1-3^{9}}{9} = \dfrac{(1-3^{10}) - (1-3^{9})}{9} = \dfrac{3^{9} - 3^{10}}{9} = 3^7 - 3^8 = 3^7\cdot (1 - 3) = -2 \cdot 3^7 = -2 \cdot 2187 = \boxed{-4374}$
#
# **Sprendimas 2.** (surandant $b_1$ ir $q$)
# $b_1 = S_1 = \dfrac{1-3^1}{9} = -\dfrac{2}{9}$.
# $b_2 = S_2 - S_1 = \dfrac{1-3^2}{9} = -\left(-\dfrac{2}{9}\right) =  -\dfrac{8}{9} + \dfrac{2}{9} = -\dfrac{6}{9}$.
# $q = \dfrac{b_2}{b_1} = 3$.
# $b_{10} = b_1 \cdot q^9 = -\dfrac{2}{9} \cdot 3^9 = -2 \cdot 3^7 = \boxed{-4374}$.
#
# 13\. Raskite lygties $x^{-2}+x^{-4}+x^{-6}+\dots = \dfrac{1}{8}$ sprendinį, jei $x>1$.
#
# **Sprendimas**
# $x^{-2}$, $x^{-4}$, $x^{-6}$, $\dots$ sudaro nykstamąją geometrinę progresiją, kurios $b_1 = x^{-2}$ ir $q = x^{-2}$ (čia $|q|<1$). Turime:
# $x^{-2}+x^{-4}+x^{-6}+\dots = b_1 \cdot \dfrac{1}{1-q} = x^{-2} \cdot \dfrac{1}{1-x^{-2}} = x^{-2} \cdot \dfrac{x^2}{x^2-1} = \dfrac{1}{x^2 - 1}$.
# Iš čia $\boxed{\dfrac{1}{x^2 - 1} = \dfrac{1}{8}} \Leftrightarrow \boxed{x^2 - 1 = 8} \Leftrightarrow \boxed{x^2 = 9} \Leftrightarrow \boxed{x = 3,\,\text{kai}\,x>1}$
#
# 14\. Didėjančiosios geometrinės progresijos, kurią sudaro $8$ nariai, pirmasis narys lygus $4$, o jos paskutinių keturių ir pirmųjų keturių narių sumų santykis lygus $625$. Raskite šios progresijos narių sumą.
# **Sprendimas.**
# $\dfrac{b_5 + b_6 + b_7 + b_8}{b_1 + b_2 + b_3 + b_4} = \dfrac{b_1q^4 + b_1q^5 + b_1q^6 + b_1q^7}{b_1 + b_1q + b_1q^2 + b_1q^3} = \dfrac{q^4(1 + q + q^2 + q^3)}{1 + q + q^2 + q^3} = q^4 = 625$.  Su didėjančios progresijos vardikliu $q > 1$ turime $q = 5$.
# Tuomet $S = b_1 \cdot \dfrac{q^8 - 1}{q - 1} = 4 \cdot \dfrac{5^8 - 1}{5 - 1} = 5^8 - 1 = 390624$.

# %% [markdown]
# ## Pasitikrinimas

# %%
import numpy as np

def ar_progression(a_1, d, lenght): 
    terms = np.r_[a_1, np.repeat(d, lenght-1)]
    return np.cumsum(terms)
    
def geom_progression(b_1, q, lenght): 
    terms = np.r_[b_1, np.repeat(q, lenght-1)]
    return np.cumprod(terms)

print('Aritmetinė progresija (9 uždavinys):', ar_progression(25, -2.5, 32).tolist())
print('Narių suma:', sum(ar_progression(25, -2.5, 32).tolist()))
print('-'*80)

with np.printoptions(precision=4):
    print('Aritmetinės progresijos posekis (10 uždavinys):', ar_progression(1/30, 1/30, 60))
    print('Narių suma:', np.sum(ar_progression(1/30, 1/30, 60)).round(5))
    print('-'*80)

print('Aritmetinė progresija (11 uždavinys):', ar_progression(2, 5, 53).tolist())
print('Narių suma:', sum(ar_progression(2, 5, 53)))
print('-'*80)

print('Aritmetinės progresijos pirmi 10 narių (12 uždavinys):', ar_progression(3, 3, 10).tolist())
print('S_25:', sum(ar_progression(3, 3, 25)))
print('S_40:', sum(ar_progression(3, 3, 40)))
print('a_33:', ar_progression(3, 3, 33)[-1])
print('-'*80)

print('Aritmetinės progresijos pirmi 10 narių (15 uždavinys):', ar_progression(4, 3, 10).tolist())
print('S_10:', sum(ar_progression(4, 3, 10)))
print('S_40:', sum(ar_progression(4, 3, 40)))
print('-'*80)

B = geom_progression(3, 4, 7)
print('Geometrinės progresijos pirmi 7 nariai (6 uždavinys):', B.tolist())
print('b_3 + b_6 =', B[2] + B[5])
print('b_4 + b_7 =', B[3] + B[6])
print('b_5 =', B[4])
print('-'*80)

with np.printoptions(precision=3):
    print('Geometrinės progresijos pirmi 35 nariai (7 uždavinys):', geom_progression(4, 24/25, 35))
    print('-'*80)

B = geom_progression(6, 2, 15)
print('Geometrinės progresijos pirmi 15 narių (9 uždavinys):', B.tolist())   
print('Narių suma:', sum(B))
print('-'*80)

with np.printoptions(precision=3, suppress=True):
    B = geom_progression(216, 1/6, 10)
    print('Geometrinės progresijos pirmi 10 narių (10 uždavinys):', B)   
    print('Narių suma:', sum(B))
    print('-'*80)

with np.printoptions(precision=3, suppress=True):
    B = geom_progression(9, 1/6, 10)
    print('Geometrinės progresijos pirmi 10 narių (11 uždavinys):', B)   
    print('Narių suma:', sum(B))
    print('-'*80)

with np.printoptions(precision=5, suppress=True):
    B = geom_progression(1/9, 1/9, 7)
    print('Geometrinės progresijos pirmi 7 nariai (13 uždavinys):', B)   
    print('Narių suma:', sum(B))
    print('-'*80)

B = geom_progression(4, 5, 8)
print('Geometrinė progresija (14 uždavinys):', B.tolist())   
print('Narių suma:', sum(B))
print('-'*80)
# Out:
# Aritmetinė progresija (9 uždavinys): [25.0, 22.5, 20.0, 17.5, 15.0, 12.5, 10.0, 7.5, 5.0, 2.5, 0.0, -2.5, -5.0, -7.5, -10.0, -12.5, -15.0, -17.5, -20.0, -22.5, -25.0, -27.5, -30.0, -32.5, -35.0, -37.5, -40.0, -42.5, -45.0, -47.5, -50.0, -52.5]
# Narių suma: -440.0
# --------------------------------------------------------------------------------
# Aritmetinės progresijos posekis (10 uždavinys): [0.0333 0.0667 0.1    0.1333 0.1667 0.2    0.2333 0.2667 0.3    0.3333
#  0.3667 0.4    0.4333 0.4667 0.5    0.5333 0.5667 0.6    0.6333 0.6667
#  0.7    0.7333 0.7667 0.8    0.8333 0.8667 0.9    0.9333 0.9667 1.
#  1.0333 1.0667 1.1    1.1333 1.1667 1.2    1.2333 1.2667 1.3    1.3333
#  1.3667 1.4    1.4333 1.4667 1.5    1.5333 1.5667 1.6    1.6333 1.6667
#  1.7    1.7333 1.7667 1.8    1.8333 1.8667 1.9    1.9333 1.9667 2.    ]
# Narių suma: 61.0
# --------------------------------------------------------------------------------
# ...
